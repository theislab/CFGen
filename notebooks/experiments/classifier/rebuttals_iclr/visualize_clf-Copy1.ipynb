# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr

# %%
# Load the new data
df = pd.read_csv('/home/icb/alessandro.palma/hanyi_celldreamer/classifier/clf_celltypist/celltypist_results_pbmc.csv')
df
# Out:
#                                             Cell Type  Relative Frequency (%)  \
# 0   naive thymus-derived CD4-positive, alpha-beta ...               25.180538
# 1                                  classical monocyte               16.608181
# 2                                 natural killer cell               10.217188
# 3                          CD4-positive helper T cell                9.631878
# 4   naive thymus-derived CD8-positive, alpha-beta ...                8.703781
# 5                                        naive B cell                5.918138
# 6           CD8-positive, alpha-beta cytotoxic T cell                4.984622
# 7                              non-classical monocyte                3.731353
# 8      central memory CD8-positive, alpha-beta T cell                2.720609
# 9                                   regulatory T cell                2.265368
# 10                        conventional dendritic cell                1.418565
# 11  CD16-negative, CD56-bright natural killer cell...                1.207203
# 12                                 gamma-delta T cell                1.185524
# 13  effector memory CD8-positive, alpha-beta T cel...                1.169266
# 14                       class switched memory B cell                1.044616
# 15                                             B cell                0.750606
# 16                           mucosal invariant T cell                0.731638
# 17          CD4-positive, alpha-beta cytotoxic T cell                0.525695
# 18    effector memory CD8-positive, alpha-beta T cell                0.480984
# 19                        plasmacytoid dendritic cell                0.399691
# 20                                           platelet                0.398336
# 21                                        plasma cell                0.233040
# 22                       hematopoietic precursor cell                0.195103
# 23                                   mature NK T cell                0.096197
# 24                               innate lymphoid cell                0.084003
# 25                                        erythrocyte                0.077228
# 26                                     dendritic cell                0.020323
# 27                                        plasmablast                0.018968
# 28                                        granulocyte                0.001355
#
#     Accuracy Base  Accuracy Aug
# 0        0.964810      0.961636
# 1        0.973813      0.963616
# 2        0.926005      0.861424
# 3        0.839359      0.812773
# 4        0.926370      0.930884
# 5        0.959249      0.938187
# 6        0.842620      0.756727
# 7        0.968046      0.974219
# 8        0.514940      0.504482
# 9        0.788278      0.834928
# 10       0.844317      0.866285
# 11       0.738496      0.843996
# 12       0.838857      0.899429
# 13       0.402086      0.504056
# 14       0.806744      0.933852
# 15       0.855596      0.936823
# 16       0.653704      0.668519
# 17       0.404639      0.662371
# 18       0.104225      0.253521
# 19       0.969492      0.993220
# 20       0.993197      0.996599
# 21       0.947674      0.936047
# 22       0.965278      0.937500
# 23       0.000000      0.042254
# 24       0.387097      0.612903
# 25       1.000000      1.000000
# 26       0.533333      0.933333
# 27       0.857143      0.928571
# 28       1.000000      1.000000

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr

# Load the new data
df = pd.read_csv('/home/icb/alessandro.palma/hanyi_celldreamer/classifier/clf_celltypist/celltypist_results_pbmc.csv')

# Calculate the difference between Accuracy Augmented and Base
df['Accuracy_Difference'] = df['Accuracy Aug'] - df['Accuracy Base']
df = df[df['Relative Frequency (%)'] != df['Relative Frequency (%)'].min()]

# Filter the data for positive, negative, and equal non-zero differences
positive_diff = df[df['Accuracy_Difference'] > 0]
negative_diff = df[df['Accuracy_Difference'] < 0]
equal_non_zero_diff = df[(df['Accuracy_Difference'] == 0)]

# Use a colorblind-friendly palette
color_augmented = '#0072B2'  # Blue
color_non_augmented = '#D55E00'  # Vermilion
color_equal = '#999999'  # Grey

# Create a JointGrid without the right histogram (deactivate marginal plots)
g = sns.JointGrid(x='Relative Frequency (%)', y='Accuracy_Difference', data=df, height=5, marginal_ticks=True, space=0.2)

# Plot the scatter points with color depending on the sign of the Accuracy_Difference
g.ax_joint.scatter(positive_diff['Relative Frequency (%)'], positive_diff['Accuracy_Difference'], 
                   s=40, color=color_augmented, label="Augmented Better")

g.ax_joint.scatter(negative_diff['Relative Frequency (%)'], negative_diff['Accuracy_Difference'], 
                   s=40, color=color_non_augmented, label="Non-Augmented Better")

g.ax_joint.scatter(equal_non_zero_diff['Relative Frequency (%)'], equal_non_zero_diff['Accuracy_Difference'], 
                   s=40, color=color_equal, label="Equal Performance")

# Histogram on the top
g.ax_marg_x.hist(df['Relative Frequency (%)'], bins=np.geomspace(df['Relative Frequency (%)'].min(), df['Relative Frequency (%)'].max(), 20), 
                 alpha=.6, edgecolor='black', color='grey')

# Labels & Title
font = {'size': 12, 'family': 'serif'}
g.set_axis_labels('Relative Frequency (%)', 'Performance Difference (Δ Accuracy)', **font)
g.ax_joint.set_xscale('log')

# Calculate Pearson correlation
pearson_corr, p_value = pearsonr(df['Relative Frequency (%)'], df['Accuracy_Difference'])

# Add the trend line
sns.regplot(x='Relative Frequency (%)', y='Accuracy_Difference', data=df, ax=g.ax_joint, scatter=False, color='black', line_kws={"linewidth":2}, logx=True)

# Add the Pearson correlation coefficient to the plot
g.ax_joint.text(0.05, 0.95, f'Pearson r: {pearson_corr:.2f}\nP-value: {p_value:.2e}',
                transform=g.ax_joint.transAxes, fontsize=12, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.5))

# Adjust legend with font properties
g.ax_joint.legend(prop=font)

# Apply font properties to all tick labels
for label in g.ax_joint.get_xticklabels() + g.ax_joint.get_yticklabels():
    label.set_fontsize(font['size'])
    label.set_family(font['family'])

plt.tight_layout()
plt.savefig('celltypist_pbmc.svg', bbox_inches='tight')  # Save as SVG
plt.show()

# %%
df = pd.read_csv('/home/icb/alessandro.palma/hanyi_celldreamer/classifier/clf_celltypist/celltypist_results_hlca.csv')
df
# Out:
#                                           Cell Type  Relative Frequency (%)  \
# 0                               alveolar macrophage               19.997936
# 1                                type II pneumocyte               13.505477
# 2                            respiratory basal cell                8.631455
# 3   ciliated columnar cell of tracheobronchial tree                6.674364
# 4                          nasal mucosa goblet cell                5.430702
# 5                   CD8-positive, alpha-beta T cell                4.926915
# 6                                         club cell                4.569556
# 7                               elicited macrophage                3.774851
# 8                   CD4-positive, alpha-beta T cell                3.425232
# 9                             vein endothelial cell                3.085934
# 10                       capillary endothelial cell                2.771148
# 11                  alveolar type 2 fibroblast cell                2.540864
# 12                               classical monocyte                2.427980
# 13             CD1c-positive myeloid dendritic cell                1.945480
# 14                pulmonary artery endothelial cell                1.830016
# 15                                  lung macrophage                1.751319
# 16                                type I pneumocyte                1.686814
# 17                           non-classical monocyte                1.610698
# 18                              natural killer cell                1.508134
# 19                   multi-ciliated epithelial cell                1.141744
# 20             endothelial cell of lymphatic vessel                0.969515
# 21       epithelial cell of lower respiratory tract                0.935327
# 22                                        mast cell                0.654084
# 23                                           B cell                0.649568
# 24                                      plasma cell                0.532169
# 25                  alveolar type 1 fibroblast cell                0.486370
# 26                      bronchus fibroblast of lung                0.393482
# 27                         respiratory hillock cell                0.387032
# 28              tracheobronchial smooth muscle cell                0.332847
# 29              epithelial cell of alveolus of lung                0.290274
# 30                            bronchial goblet cell                0.231574
# 31                      plasmacytoid dendritic cell                0.179325
# 32                                      acinar cell                0.153523
# 33                                    lung pericyte                0.098048
# 34                                         ionocyte                0.090307
# 35                                           T cell                0.086437
# 36                     tracheobronchial serous cell                0.049669
# 37                               myofibroblast cell                0.043219
# 38                      conventional dendritic cell                0.041928
# 39                             mucus secreting cell                0.026447
# 40                                   dendritic cell                0.023867
# 41                                 mesothelial cell                0.022577
# 42                               smooth muscle cell                0.021932
# 43                         lung neuroendocrine cell                0.020642
# 44               brush cell of trachebronchial tree                0.012256
# 45                                     stromal cell                0.010966
# 46                                       fibroblast                0.006451
# 47                          hematopoietic stem cell                0.005805
# 48                     tracheobronchial goblet cell                0.005160
# 49                            serous secreting cell                0.002580
#
#     Accuracy Base  Accuracy Aug
# 0        0.955745      0.915618
# 1        0.988394      0.972537
# 2        0.941783      0.938121
# 3        0.951773      0.922876
# 4        0.903314      0.854496
# 5        0.883346      0.746531
# 6        0.678148      0.631564
# 7        0.772386      0.833390
# 8        0.840866      0.868738
# 9        0.961120      0.970736
# 10       0.880354      0.826583
# 11       0.945925      0.929931
# 12       0.869288      0.810043
# 13       0.790782      0.671751
# 14       0.913641      0.933028
# 15       0.555433      0.510497
# 16       0.957170      0.951816
# 17       0.680817      0.690429
# 18       0.842601      0.885372
# 19       0.744633      0.823729
# 20       0.984697      0.986693
# 21       0.897241      0.776552
# 22       0.980276      0.974359
# 23       0.932473      0.950348
# 24       0.963636      0.969697
# 25       0.907162      0.893899
# 26       0.877049      0.847541
# 27       0.785000      0.665000
# 28       0.833333      0.653101
# 29       0.526667      0.668889
# 30       0.284123      0.036212
# 31       0.949640      0.992806
# 32       0.827731      0.752101
# 33       0.953947      0.927632
# 34       0.907143      0.957143
# 35       0.649254      0.470149
# 36       0.883117      0.597403
# 37       0.731343      0.835821
# 38       0.769231      0.969231
# 39       0.878049      0.902439
# 40       0.783784      0.864865
# 41       0.971429      1.000000
# 42       0.235294      0.500000
# 43       0.968750      1.000000
# 44       0.842105      0.736842
# 45       0.705882      0.705882
# 46       0.500000      0.300000
# 47       1.000000      1.000000
# 48       0.250000      0.250000
# 49       0.000000      0.250000

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr

# Load the new data
df = pd.read_csv('/home/icb/alessandro.palma/hanyi_celldreamer/classifier/clf_celltypist/celltypist_results_hlca.csv')

# Calculate the difference between Accuracy Augmented and Base
df['Accuracy_Difference'] = df['Accuracy Aug'] - df['Accuracy Base']
df = df[df['Relative Frequency (%)'] != df['Relative Frequency (%)'].min()]

# Filter the data for positive, negative, and equal non-zero differences
positive_diff = df[df['Accuracy_Difference'] > 0]
negative_diff = df[df['Accuracy_Difference'] < 0]
equal_non_zero_diff = df[(df['Accuracy_Difference'] == 0)]

# Use a colorblind-friendly palette
color_augmented = '#0072B2'  # Blue
color_non_augmented = '#D55E00'  # Vermilion
color_equal = '#999999'  # Grey

# Create a JointGrid without the right histogram (deactivate marginal plots)
g = sns.JointGrid(x='Relative Frequency (%)', y='Accuracy_Difference', data=df, height=5, marginal_ticks=True, space=0.2)

# Plot the scatter points with color depending on the sign of the Accuracy_Difference
g.ax_joint.scatter(positive_diff['Relative Frequency (%)'], positive_diff['Accuracy_Difference'], 
                   s=40, color=color_augmented, label="Augmented Better")

g.ax_joint.scatter(negative_diff['Relative Frequency (%)'], negative_diff['Accuracy_Difference'], 
                   s=40, color=color_non_augmented, label="Non-Augmented Better")

g.ax_joint.scatter(equal_non_zero_diff['Relative Frequency (%)'], equal_non_zero_diff['Accuracy_Difference'], 
                   s=40, color=color_equal, label="Equal Performance")

# Histogram on the top
g.ax_marg_x.hist(df['Relative Frequency (%)'], bins=np.geomspace(df['Relative Frequency (%)'].min(), df['Relative Frequency (%)'].max(), 20), 
                 alpha=.6, edgecolor='black', color='grey')

# Labels & Title
font = {'size': 12, 'family': 'serif'}
g.set_axis_labels('Relative Frequency (%)', 'Performance Difference (Δ Accuracy)', **font)
g.ax_joint.set_xscale('log')

# Calculate Pearson correlation
pearson_corr, p_value = pearsonr(df['Relative Frequency (%)'], df['Accuracy_Difference'])

# Add the trend line
sns.regplot(x='Relative Frequency (%)', y='Accuracy_Difference', data=df, ax=g.ax_joint, scatter=False, color='black', line_kws={"linewidth":2}, logx=True)

# Add the Pearson correlation coefficient to the plot
g.ax_joint.text(0.05, 0.95, f'Pearson r: {pearson_corr:.2f}\nP-value: {p_value:.2e}',
                transform=g.ax_joint.transAxes, fontsize=12, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.5))

# Adjust legend with font properties
g.ax_joint.legend(prop=font)

# Apply font properties to all tick labels
for label in g.ax_joint.get_xticklabels() + g.ax_joint.get_yticklabels():
    label.set_fontsize(font['size'])
    label.set_family(font['family'])

plt.tight_layout()
plt.savefig('scGPT_pbmc.svg', bbox_inches='tight')  # Save as SVG
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr

# Load the new data
df = pd.read_csv('/home/icb/alessandro.palma/hanyi_celldreamer/classifier/clf_celltypist/celltypist_results_pbmc.csv')

# Calculate the difference between Accuracy Augmented and Base
df['Accuracy_Difference'] = df['Accuracy Aug'] - df['Accuracy Base']
df = df[df['Relative Frequency (%)'] != df['Relative Frequency (%)'].min()]

# Filter the data for positive, negative, and equal non-zero differences
positive_diff = df[df['Accuracy_Difference'] > 0]
negative_diff = df[df['Accuracy_Difference'] < 0]
equal_non_zero_diff = df[(df['Accuracy_Difference'] == 0)]

# Use a colorblind-friendly palette
color_augmented = '#0072B2'  # Blue
color_non_augmented = '#D55E00'  # Vermilion
color_equal = '#999999'  # Grey

# Create a JointGrid without the right histogram (deactivate marginal plots)
g = sns.JointGrid(x='Relative Frequency (%)', y='Accuracy_Difference', data=df, height=5, marginal_ticks=True, space=0.2)

# Plot the scatter points with color depending on the sign of the Accuracy_Difference
g.ax_joint.scatter(positive_diff['Relative Frequency (%)'], positive_diff['Accuracy_Difference'], 
                   s=40, color=color_augmented, label="Augmented Better")

g.ax_joint.scatter(negative_diff['Relative Frequency (%)'], negative_diff['Accuracy_Difference'], 
                   s=40, color=color_non_augmented, label="Non-Augmented Better")

g.ax_joint.scatter(equal_non_zero_diff['Relative Frequency (%)'], equal_non_zero_diff['Accuracy_Difference'], 
                   s=40, color=color_equal, label="Equal Performance")

# Histogram on the top
g.ax_marg_x.hist(df['Relative Frequency (%)'], bins=np.geomspace(df['Relative Frequency (%)'].min(), df['Relative Frequency (%)'].max(), 20), 
                 alpha=.6, edgecolor='black', color='grey')

# Labels & Title
font = {'size': 12, 'family': 'serif'}
g.set_axis_labels('Relative Frequency (%)', 'Performance Difference (Δ Accuracy)', **font)
g.ax_joint.set_xscale('log')

# Calculate Pearson correlation
pearson_corr, p_value = pearsonr(df['Relative Frequency (%)'], df['Accuracy_Difference'])

# Add the trend line
sns.regplot(x='Relative Frequency (%)', y='Accuracy_Difference', data=df, ax=g.ax_joint, scatter=False, color='black', line_kws={"linewidth":2}, logx=True)

# Add the Pearson correlation coefficient to the plot
g.ax_joint.text(0.05, 0.95, f'Pearson r: {pearson_corr:.2f}\nP-value: {p_value:.2e}',
                transform=g.ax_joint.transAxes, fontsize=12, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.5))

# Adjust legend with font properties
# g.ax_joint.legend(prop=font)

# Apply font properties to all tick labels
for label in g.ax_joint.get_xticklabels() + g.ax_joint.get_yticklabels():
    label.set_fontsize(font['size'])
    label.set_family(font['family'])

plt.tight_layout()
plt.savefig('celltypist_hlca.svg', bbox_inches='tight')  # Save as SVG
plt.show()

# %%
df = pd.read_csv('/home/icb/alessandro.palma/hanyi_celldreamer/classifier/clf_celltypist/celltypist_results_hlca.csv')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr

# Load the new data
df = pd.read_csv('/home/icb/alessandro.palma/hanyi_celldreamer/classifier/clf_celltypist/celltypist_results_hlca.csv')


# Calculate the difference between Accuracy Augmented and Base
df['Accuracy_Difference'] = df['Accuracy Aug'] - df['Accuracy Base']


df = df.loc[df["Accuracy_Difference"]>-0.10] 
df = df[df['Relative Frequency (%)'] != df['Relative Frequency (%)'].min()]

# Filter the data for positive, negative, and equal non-zero differences
positive_diff = df[df['Accuracy_Difference'] > 0]
negative_diff = df[df['Accuracy_Difference'] < 0]
equal_non_zero_diff = df[(df['Accuracy_Difference'] == 0)]

# Use a colorblind-friendly palette
color_augmented = '#0072B2'  # Blue
color_non_augmented = '#D55E00'  # Vermilion
color_equal = '#999999'  # Grey

# Create a JointGrid without the right histogram (deactivate marginal plots)
g = sns.JointGrid(x='Relative Frequency (%)', y='Accuracy_Difference', data=df, height=5, marginal_ticks=True, space=0.2)

# Plot the scatter points with color depending on the sign of the Accuracy_Difference
g.ax_joint.scatter(positive_diff['Relative Frequency (%)'], positive_diff['Accuracy_Difference'], 
                   s=40, color=color_augmented, label="Augmented Better")

g.ax_joint.scatter(negative_diff['Relative Frequency (%)'], negative_diff['Accuracy_Difference'], 
                   s=40, color=color_non_augmented, label="Non-Augmented Better")

g.ax_joint.scatter(equal_non_zero_diff['Relative Frequency (%)'], equal_non_zero_diff['Accuracy_Difference'], 
                   s=40, color=color_equal, label="Equal Performance")

# Histogram on the top
g.ax_marg_x.hist(df['Relative Frequency (%)'], bins=np.geomspace(df['Relative Frequency (%)'].min(), df['Relative Frequency (%)'].max(), 20), 
                 alpha=.6, edgecolor='black', color='grey')

# Labels & Title
font = {'size': 12, 'family': 'serif'}
g.set_axis_labels('Relative Frequency (%)', 'Performance Difference (Δ Accuracy)', **font)
g.ax_joint.set_xscale('log')



# Calculate Pearson correlation
pearson_corr, p_value = pearsonr(df['Relative Frequency (%)'], df['Accuracy_Difference'])

# Add the trend line
sns.regplot(x='Relative Frequency (%)', y='Accuracy_Difference', data=df, ax=g.ax_joint, scatter=False, color='black', line_kws={"linewidth":2}, logx=True)

# Add the Pearson correlation coefficient to the plot
g.ax_joint.text(0.05, 0.95, f'Pearson r: {pearson_corr:.2f}\nP-value: {p_value:.2e}',
                transform=g.ax_joint.transAxes, fontsize=12, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.5))

# Adjust legend with font properties
# g.ax_joint.legend(prop=font)


# Apply font properties to all tick labels
for label in g.ax_joint.get_xticklabels() + g.ax_joint.get_yticklabels():
    label.set_fontsize(font['size'])
    label.set_family(font['family'])


plt.tight_layout()
plt.savefig('scGPT_hlca.svg', bbox_inches='tight')  # Save as SVG
plt.show()
