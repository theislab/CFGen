platelet: 0.9965986394557823
effector memory CD8-positive, alpha-beta T cell: 0.17746478873239438
mucosal invariant T cell: 0.7055555555555556
plasmacytoid dendritic cell: 1.0
innate lymphoid cell: 0.3709677419354839
B cell: 0.23826714801444043
plasmablast: 1.0
plasma cell: 0.9186046511627907
hematopoietic precursor cell: 0.875
dendritic cell: 0.6
mature NK T cell: 0.0
erythrocyte: 1.0
granulocyte: 1.0"""

# %%
data_aug_cellflow_rare_1000="""classical monocyte: 0.9740577581987273
CD4-positive helper T cell: 0.7339991559994373
naive thymus-derived CD8-positive, alpha-beta T cell: 0.8074408468244084
naive thymus-derived CD4-positive, alpha-beta T cell: 0.90788270110304
CD16-negative, CD56-bright natural killer cell, human: 0.5970819304152637
natural killer cell: 0.9005436944702294
gamma-delta T cell: 0.49714285714285716
naive B cell: 0.9828296703296703
non-classical monocyte: 0.9629629629629629
central memory CD8-positive, alpha-beta T cell: 0.3754980079681275
conventional dendritic cell: 0.7468958930276982
CD8-positive, alpha-beta cytotoxic T cell: 0.7779287849959228
regulatory T cell: 0.2996411483253589
class switched memory B cell: 0.45265888456549935
CD4-positive, alpha-beta cytotoxic T cell: 0.04381443298969072
effector memory CD8-positive, alpha-beta T cell, terminally differentiated: 0.1332560834298957
platelet: 0.9965986394557823
effector memory CD8-positive, alpha-beta T cell: 0.10985915492957747
mucosal invariant T cell: 0.6555555555555556
plasmacytoid dendritic cell: 0.9966101694915255
innate lymphoid cell: 0.12903225806451613
B cell: 0.09386281588447654
plasmablast: 1.0
plasma cell: 0.9767441860465116
hematopoietic precursor cell: 0.9583333333333334
dendritic cell: 0.4666666666666667
mature NK T cell: 0.0
erythrocyte: 1.0
granulocyte: 1.0"""

# %%
# Create a dictionary to store the cell types and their accuracies
acc_non_aug = {}

# Process each line in the data string
for line in data_non_aug.strip().split('\n'):
    # Split each line into cell type and accuracy based on the colon separator
    cell_type, accuracy = line.split(':')
    # Trim whitespace and convert accuracy to float, then store in dictionary
    acc_non_aug[cell_type.strip()] = float(accuracy.strip())

# Now the dictionary `cell_type_accuracy` has all the cell types as keys and their accuracies as values
for k in acc_non_aug.keys():
    print(k)
    print(acc_non_aug[k])
# Out:
# classical monocyte
# 0.980257790830478
# CD4-positive helper T cell
# 0.8048952032634689
# naive thymus-derived CD8-positive, alpha-beta T cell
# 0.8250311332503113
# naive thymus-derived CD4-positive, alpha-beta T cell
# 0.8739843960182944
# CD16-negative, CD56-bright natural killer cell, human
# 0.6554433221099888
# natural killer cell
# 0.913008884763294
# gamma-delta T cell
# 0.49142857142857144
# naive B cell
# 0.9581043956043956
# non-classical monocyte
# 0.94880174291939
# central memory CD8-positive, alpha-beta T cell
# 0.45169322709163345
# conventional dendritic cell
# 0.7860553963705826
# CD8-positive, alpha-beta cytotoxic T cell
# 0.7760260940472955
# regulatory T cell
# 0.27631578947368424
# class switched memory B cell
# 0.5110246433203631
# CD4-positive, alpha-beta cytotoxic T cell
# 0.059278350515463915
# effector memory CD8-positive, alpha-beta T cell, terminally differentiated
# 0.21205098493626884
# platelet
# 1.0
# effector memory CD8-positive, alpha-beta T cell
# ...

# %%
# Create a dictionary to store the cell types and their accuracies
acc_aug_cellflow_std = {}

# Process each line in the data string
for line in data_aug_cellflow_std.strip().split('\n'):
    # Split each line into cell type and accuracy based on the colon separator
    cell_type, accuracy = line.split(':')
    # Trim whitespace and convert accuracy to float, then store in dictionary
    acc_aug_cellflow_std[cell_type.strip()] = float(accuracy.strip())

# %%
# Create a dictionary to store the cell types and their accuracies
acc_aug_cellflow_std = {}

# Process each line in the data string
for line in data_aug_cellflow_std.strip().split('\n'):
    # Split each line into cell type and accuracy based on the colon separator
    cell_type, accuracy = line.split(':')
    # Trim whitespace and convert accuracy to float, then store in dictionary
    acc_aug_cellflow_std[cell_type.strip()] = float(accuracy.strip())

# %%
# Create a dictionary to store the cell types and their accuracies
acc_aug_cellflow_less_100000 = {}

# Process each line in the data string
for line in data_aug_cellflow_less_100000.strip().split('\n'):
    # Split each line into cell type and accuracy based on the colon separator
    cell_type, accuracy = line.split(':')
    # Trim whitespace and convert accuracy to float, then store in dictionary
    acc_aug_cellflow_less_100000[cell_type.strip()] = float(accuracy.strip())

# %%
# Create a dictionary to store the cell types and their accuracies
acc_aug_cellflow_less_10000 = {}

# Process each line in the data string
for line in data_aug_cellflow_less_10000.strip().split('\n'):
    # Split each line into cell type and accuracy based on the colon separator
    cell_type, accuracy = line.split(':')
    # Trim whitespace and convert accuracy to float, then store in dictionary
    acc_aug_cellflow_less_10000[cell_type.strip()] = float(accuracy.strip())

# %%
# Create a dictionary to store the cell types and their accuracies
acc_aug_cellflow_less_1000 = {}

# Process each line in the data string
for line in data_aug_cellflow_less_1000.strip().split('\n'):
    # Split each line into cell type and accuracy based on the colon separator
    cell_type, accuracy = line.split(':')
    # Trim whitespace and convert accuracy to float, then store in dictionary
    acc_aug_cellflow_less_1000[cell_type.strip()] = float(accuracy.strip())

# %%
# Create a dictionary to store the cell types and their accuracies
acc_aug_cellflow_rare_5000 = {}

# Process each line in the data string
for line in data_aug_cellflow_rare_5000.strip().split('\n'):
    # Split each line into cell type and accuracy based on the colon separator
    cell_type, accuracy = line.split(':')
    # Trim whitespace and convert accuracy to float, then store in dictionary
    acc_aug_cellflow_rare_5000[cell_type.strip()] = float(accuracy.strip())

# %%
# Create a dictionary to store the cell types and their accuracies
acc_aug_cellflow_rare_1000 = {}

# Process each line in the data string
for line in data_aug_cellflow_rare_1000.strip().split('\n'):
    # Split each line into cell type and accuracy based on the colon separator
    cell_type, accuracy = line.split(':')
    # Trim whitespace and convert accuracy to float, then store in dictionary
    acc_aug_cellflow_rare_1000[cell_type.strip()] = float(accuracy.strip())

# %% [markdown]
# Create data frame

# %%
results = pd.read_csv("/home/icb/alessandro.palma/environment/cfgen/project_folder/classification_experiments/hanyi_celldreamer/classifier/scGPT/scGPT_results.csv")

# %%
results.columns = ["Cell Type",
                   "Relative Frequency (%)",
                   "Accuracy Base", 
                   "Accuracy cellFlow std", 
                  ]
results
# Out:
#                                             Cell Type  Relative Frequency (%)  \
# 0   naive thymus-derived CD4-positive, alpha-beta ...               25.180538
# 1                                  classical monocyte               16.608181
# 2                                 natural killer cell               10.217188
# 3                          CD4-positive helper T cell                9.631878
# 4   naive thymus-derived CD8-positive, alpha-beta ...                8.703781
# 5                                        naive B cell                5.918138
# 6           CD8-positive, alpha-beta cytotoxic T cell                4.984622
# 7                              non-classical monocyte                3.731353
# 8      central memory CD8-positive, alpha-beta T cell                2.720609
# 9                                   regulatory T cell                2.265368
# 10                        conventional dendritic cell                1.418565
# ...

# %%
results["Accuracy cellFlow 100000"] = 0
results["Accuracy cellFlow 10000"] = 0
results["Accuracy cellFlow 1000"] = 0
results["Accuracy cellFlow rare 5000"] = 0
results["Accuracy cellFlow rare 1000"] = 0

# %%
for index, row in results.iterrows():
    cell_type = row['Cell Type']
    results.at[index, 'Accuracy Base'] = acc_non_aug[cell_type]
    results.at[index, 'Accuracy cellFlow std'] = acc_aug_cellflow_std[cell_type]
    results.at[index, 'Accuracy cellFlow 100000'] = acc_aug_cellflow_less_100000[cell_type]
    results.at[index, 'Accuracy cellFlow 10000'] = acc_aug_cellflow_less_10000[cell_type]
    results.at[index, 'Accuracy cellFlow 1000'] = acc_aug_cellflow_less_1000[cell_type]
    results.at[index, 'Accuracy cellFlow rare 5000'] = acc_aug_cellflow_rare_5000[cell_type]
    results.at[index, 'Accuracy cellFlow rare 1000'] = acc_aug_cellflow_rare_1000[cell_type]
# Out:
# /var/tmp/ipykernel_2562015/3887792134.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.901802528921173' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   results.at[index, 'Accuracy cellFlow 100000'] = acc_aug_cellflow_less_100000[cell_type]
# /var/tmp/ipykernel_2562015/3887792134.py:6: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.9080441216034436' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   results.at[index, 'Accuracy cellFlow 10000'] = acc_aug_cellflow_less_10000[cell_type]
# /var/tmp/ipykernel_2562015/3887792134.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.90788270110304' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
# ...

# %%
results
# Out:
#                                             Cell Type  Relative Frequency (%)  \
# 0   naive thymus-derived CD4-positive, alpha-beta ...               25.180538
# 1                                  classical monocyte               16.608181
# 2                                 natural killer cell               10.217188
# 3                          CD4-positive helper T cell                9.631878
# 4   naive thymus-derived CD8-positive, alpha-beta ...                8.703781
# 5                                        naive B cell                5.918138
# 6           CD8-positive, alpha-beta cytotoxic T cell                4.984622
# 7                              non-classical monocyte                3.731353
# 8      central memory CD8-positive, alpha-beta T cell                2.720609
# 9                                   regulatory T cell                2.265368
# 10                        conventional dendritic cell                1.418565
# ...
