# %%
import pandas as pd

# %%
data_non_aug_recall = """classical monocyte: 0.980257790830478
CD4-positive helper T cell: 0.8048952032634689
naive thymus-derived CD8-positive, alpha-beta T cell: 0.8250311332503113
naive thymus-derived CD4-positive, alpha-beta T cell: 0.8739843960182944
CD16-negative, CD56-bright natural killer cell, human: 0.6554433221099888
natural killer cell: 0.913008884763294
gamma-delta T cell: 0.49142857142857144
naive B cell: 0.9581043956043956
non-classical monocyte: 0.94880174291939
central memory CD8-positive, alpha-beta T cell: 0.45169322709163345
conventional dendritic cell: 0.7860553963705826
CD8-positive, alpha-beta cytotoxic T cell: 0.7760260940472955
regulatory T cell: 0.27631578947368424
class switched memory B cell: 0.5110246433203631
CD4-positive, alpha-beta cytotoxic T cell: 0.059278350515463915
effector memory CD8-positive, alpha-beta T cell, terminally differentiated: 0.21205098493626884
platelet: 1.0
effector memory CD8-positive, alpha-beta T cell: 0.10140845070422536
mucosal invariant T cell: 0.6925925925925925
plasmacytoid dendritic cell: 0.9966101694915255
innate lymphoid cell: 0.20967741935483872
B cell: 0.20577617328519857
plasmablast: 0.9285714285714286
plasma cell: 0.9709302325581395
hematopoietic precursor cell: 0.9652777777777778
dendritic cell: 0.4666666666666667
mature NK T cell: 0.0
erythrocyte: 1.0
granulocyte: 1.0"""

# %%
data_aug_recall = """classical monocyte: 0.9595366291401534
CD4-positive helper T cell: 0.7144464762976509
naive thymus-derived CD8-positive, alpha-beta T cell: 0.8307907845579079
naive thymus-derived CD4-positive, alpha-beta T cell: 0.8855528652138822
CD16-negative, CD56-bright natural killer cell, human: 0.712682379349046
natural killer cell: 0.8604959554435752
gamma-delta T cell: 0.5988571428571429
naive B cell: 0.9734432234432234
non-classical monocyte: 0.9691358024691358
central memory CD8-positive, alpha-beta T cell: 0.3331673306772908
conventional dendritic cell: 0.8252148997134671
CD8-positive, alpha-beta cytotoxic T cell: 0.6618646371296548
regulatory T cell: 0.3672248803827751
class switched memory B cell: 0.7263294422827496
CD4-positive, alpha-beta cytotoxic T cell: 0.12886597938144329
effector memory CD8-positive, alpha-beta T cell, terminally differentiated: 0.2514484356894554
platelet: 0.9965986394557823
effector memory CD8-positive, alpha-beta T cell: 0.22253521126760564
mucosal invariant T cell: 0.7037037037037037
plasmacytoid dendritic cell: 1.0
innate lymphoid cell: 0.3870967741935484
B cell: 0.4043321299638989
plasmablast: 1.0
plasma cell: 0.8953488372093024
hematopoietic precursor cell: 0.875
dendritic cell: 0.6666666666666666
mature NK T cell: 0.056338028169014086
erythrocyte: 1.0
granulocyte: 1.0"""

# %%
data_aug_recall_scdiffusion = """classical monocyte: 0.9750367107195301
CD4-positive helper T cell: 0.778309185539457
naive thymus-derived CD8-positive, alpha-beta T cell: 0.8267434620174346
naive thymus-derived CD4-positive, alpha-beta T cell: 0.8843691148775894
CD16-negative, CD56-bright natural killer cell, human: 0.6891133557800224
natural killer cell: 0.9018697785439597
gamma-delta T cell: 0.49028571428571427
naive B cell: 0.9578754578754579
non-classical monocyte: 0.9567901234567902
central memory CD8-positive, alpha-beta T cell: 0.47758964143426297
conventional dendritic cell: 0.7774594078319007
CD8-positive, alpha-beta cytotoxic T cell: 0.7961402555042131
regulatory T cell: 0.3235645933014354
class switched memory B cell: 0.5966277561608301
CD4-positive, alpha-beta cytotoxic T cell: 0.061855670103092786
effector memory CD8-positive, alpha-beta T cell, terminally differentiated: 0.1425260718424102
platelet: 1.0
effector memory CD8-positive, alpha-beta T cell: 0.12394366197183099
mucosal invariant T cell: 0.6703703703703704
plasmacytoid dendritic cell: 0.9966101694915255
innate lymphoid cell: 0.1774193548387097
B cell: 0.2003610108303249
plasmablast: 0.9285714285714286
plasma cell: 0.9534883720930233
hematopoietic precursor cell: 0.9652777777777778
dendritic cell: 0.4666666666666667
mature NK T cell: 0.0
erythrocyte: 1.0
granulocyte: 1.0"""

# %%
data_aug_recall_scvi = """classical monocyte: 0.9730788056779246
CD4-positive helper T cell: 0.7231678154452102
naive thymus-derived CD8-positive, alpha-beta T cell: 0.7949875466998755
naive thymus-derived CD4-positive, alpha-beta T cell: 0.9006187785848803
CD16-negative, CD56-bright natural killer cell, human: 0.5791245791245792
natural killer cell: 0.898687176767007
gamma-delta T cell: 0.5234285714285715
naive B cell: 0.9837454212454212
non-classical monocyte: 0.9520697167755992
central memory CD8-positive, alpha-beta T cell: 0.34760956175298807
conventional dendritic cell: 0.7488061127029608
CD8-positive, alpha-beta cytotoxic T cell: 0.784452296819788
regulatory T cell: 0.284688995215311
class switched memory B cell: 0.4682230869001297
CD4-positive, alpha-beta cytotoxic T cell: 0.030927835051546393
effector memory CD8-positive, alpha-beta T cell, terminally differentiated: 0.1320973348783314
platelet: 1.0
effector memory CD8-positive, alpha-beta T cell: 0.11267605633802817
mucosal invariant T cell: 0.6370370370370371
plasmacytoid dendritic cell: 0.9932203389830508
innate lymphoid cell: 0.11290322580645161
B cell: 0.09386281588447654
plasmablast: 0.9285714285714286
plasma cell: 0.9593023255813954
hematopoietic precursor cell: 0.9583333333333334
dendritic cell: 0.4666666666666667
mature NK T cell: 0.0
erythrocyte: 1.0
granulocyte: 1.0"""

# %%
# Create a dictionary to store the cell types and their accuracies
rec_non_aug = {}

# Process each line in the data string
for line in data_non_aug_recall.strip().split('\n'):
    # Split each line into cell type and accuracy based on the colon separator
    cell_type, accuracy = line.split(':')
    # Trim whitespace and convert accuracy to float, then store in dictionary
    rec_non_aug[cell_type.strip()] = float(accuracy.strip())

# Now the dictionary `cell_type_accuracy` has all the cell types as keys and their accuracies as values
for k in rec_non_aug.keys():
    print(k)
    print(rec_non_aug[k])
# Out:
# classical monocyte
# 0.980257790830478
# CD4-positive helper T cell
# 0.8048952032634689
# naive thymus-derived CD8-positive, alpha-beta T cell
# 0.8250311332503113
# naive thymus-derived CD4-positive, alpha-beta T cell
# 0.8739843960182944
# CD16-negative, CD56-bright natural killer cell, human
# 0.6554433221099888
# natural killer cell
# 0.913008884763294
# gamma-delta T cell
# 0.49142857142857144
# naive B cell
# 0.9581043956043956
# non-classical monocyte
# 0.94880174291939
# central memory CD8-positive, alpha-beta T cell
# 0.45169322709163345
# conventional dendritic cell
# 0.7860553963705826
# CD8-positive, alpha-beta cytotoxic T cell
# 0.7760260940472955
# regulatory T cell
# 0.27631578947368424
# class switched memory B cell
# 0.5110246433203631
# CD4-positive, alpha-beta cytotoxic T cell
# 0.059278350515463915
# effector memory CD8-positive, alpha-beta T cell, terminally differentiated
# 0.21205098493626884
# platelet
# 1.0
# effector memory CD8-positive, alpha-beta T cell
# 0.10140845070422536
# mucosal invariant T cell
# 0.6925925925925925
# plasmacytoid dendritic cell
# 0.9966101694915255
# innate lymphoid cell
# 0.20967741935483872
# B cell
# 0.20577617328519857
# plasmablast
# 0.9285714285714286
# plasma cell
# 0.9709302325581395
# hematopoietic precursor cell
# 0.9652777777777778
# dendritic cell
# 0.4666666666666667
# mature NK T cell
# 0.0
# erythrocyte
# 1.0
# granulocyte
# 1.0

# %%
# Create a dictionary to store the cell types and their accuracies
rec_aug_cellflow = {}

# Process each line in the data string
for line in data_aug_recall.strip().split('\n'):
    # Split each line into cell type and accuracy based on the colon separator
    cell_type, accuracy = line.split(':')
    # Trim whitespace and convert accuracy to float, then store in dictionary
    rec_aug_cellflow[cell_type.strip()] = float(accuracy.strip())

# %%
# Create a dictionary to store the cell types and their accuracies
rec_aug_recall_scdiffusion = {}

# Process each line in the data string
for line in data_aug_recall_scdiffusion.strip().split('\n'):
    # Split each line into cell type and accuracy based on the colon separator
    cell_type, accuracy = line.split(':')
    # Trim whitespace and convert accuracy to float, then store in dictionary
    rec_aug_recall_scdiffusion[cell_type.strip()] = float(accuracy.strip())

# %%
# Create a dictionary to store the cell types and their accuracies
rec_aug_recall_scvi = {}

# Process each line in the data string
for line in data_aug_recall_scvi.strip().split('\n'):
    # Split each line into cell type and accuracy based on the colon separator
    cell_type, accuracy = line.split(':')
    # Trim whitespace and convert accuracy to float, then store in dictionary
    rec_aug_recall_scvi[cell_type.strip()] = float(accuracy.strip())

# %% [markdown]
# Create data frame

# %%
results = pd.read_csv("/home/icb/alessandro.palma/environment/cfgen/project_folder/classification_experiments/hanyi_celldreamer/classifier/scGPT/scGPT_results.csv")

# %%
results.columns = ["Cell Type",
                   "Relative Frequency (%)",
                   "Recall Base", 
                   "Recall cellFlow", 
                  ]
results
# Out:
#                                             Cell Type  Relative Frequency (%)  \
# 0   naive thymus-derived CD4-positive, alpha-beta ...               25.180538
# 1                                  classical monocyte               16.608181
# 2                                 natural killer cell               10.217188
# 3                          CD4-positive helper T cell                9.631878
# 4   naive thymus-derived CD8-positive, alpha-beta ...                8.703781
# 5                                        naive B cell                5.918138
# 6           CD8-positive, alpha-beta cytotoxic T cell                4.984622
# 7                              non-classical monocyte                3.731353
# 8      central memory CD8-positive, alpha-beta T cell                2.720609
# 9                                   regulatory T cell                2.265368
# 10                        conventional dendritic cell                1.418565
# 11  CD16-negative, CD56-bright natural killer cell...                1.207203
# 12                                 gamma-delta T cell                1.185524
# 13  effector memory CD8-positive, alpha-beta T cel...                1.169266
# 14                       class switched memory B cell                1.044616
# 15                                             B cell                0.750606
# 16                           mucosal invariant T cell                0.731638
# 17          CD4-positive, alpha-beta cytotoxic T cell                0.525695
# 18    effector memory CD8-positive, alpha-beta T cell                0.480984
# 19                        plasmacytoid dendritic cell                0.399691
# 20                                           platelet                0.398336
# 21                                        plasma cell                0.233040
# 22                       hematopoietic precursor cell                0.195103
# 23                                   mature NK T cell                0.096197
# 24                               innate lymphoid cell                0.084003
# 25                                        erythrocyte                0.077228
# 26                                     dendritic cell                0.020323
# 27                                        plasmablast                0.018968
# 28                                        granulocyte                0.001355
#
#     Recall Base  Recall cellFlow
# 0      0.873984         0.899704
# 1      0.980339         0.961821
# 2      0.913009         0.850550
# 3      0.804895         0.753974
# 4      0.825031         0.786115
# 5      0.957875         0.975733
# 6      0.776026         0.669204
# 7      0.948802         0.963326
# 8      0.451693         0.331673
# 9      0.276316         0.319976
# 10     0.786055         0.840497
# 11     0.655443         0.704826
# 12     0.491429         0.633143
# 13     0.212051         0.269988
# 14     0.511025         0.705577
# 15     0.205776         0.391697
# 16     0.692593         0.700000
# 17     0.059278         0.134021
# 18     0.101408         0.228169
# 19     0.996610         1.000000
# 20     1.000000         0.996599
# 21     0.970930         0.901163
# 22     0.965278         0.861111
# 23     0.000000         0.056338
# 24     0.209677         0.403226
# 25     1.000000         1.000000
# 26     0.466667         0.800000
# 27     0.928571         1.000000
# 28     1.000000         1.000000

# %%
results["Recall scDiffusion"] = 0
results["Recall scVI"] = 0

# %%
for index, row in results.iterrows():
    cell_type = row['Cell Type']
    results.at[index, 'Recall Base'] = rec_non_aug[cell_type]
    results.at[index, 'Recall cellFlow'] = rec_aug_cellflow[cell_type]
    results.at[index, 'Recall scDiffusion'] = rec_aug_recall_scdiffusion[cell_type]
    results.at[index, 'Recall scVI'] = rec_aug_recall_scvi[cell_type]
# Out:
# /var/tmp/ipykernel_2580715/3203587410.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.8843691148775894' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   results.at[index, 'Recall scDiffusion'] = rec_aug_recall_scdiffusion[cell_type]
# /var/tmp/ipykernel_2580715/3203587410.py:6: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.9006187785848803' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   results.at[index, 'Recall scVI'] = rec_aug_recall_scvi[cell_type]

# %%
results
# Out:
#                                             Cell Type  Relative Frequency (%)  \
# 0   naive thymus-derived CD4-positive, alpha-beta ...               25.180538
# 1                                  classical monocyte               16.608181
# 2                                 natural killer cell               10.217188
# 3                          CD4-positive helper T cell                9.631878
# 4   naive thymus-derived CD8-positive, alpha-beta ...                8.703781
# 5                                        naive B cell                5.918138
# 6           CD8-positive, alpha-beta cytotoxic T cell                4.984622
# 7                              non-classical monocyte                3.731353
# 8      central memory CD8-positive, alpha-beta T cell                2.720609
# 9                                   regulatory T cell                2.265368
# 10                        conventional dendritic cell                1.418565
# 11  CD16-negative, CD56-bright natural killer cell...                1.207203
# 12                                 gamma-delta T cell                1.185524
# 13  effector memory CD8-positive, alpha-beta T cel...                1.169266
# 14                       class switched memory B cell                1.044616
# 15                                             B cell                0.750606
# 16                           mucosal invariant T cell                0.731638
# 17          CD4-positive, alpha-beta cytotoxic T cell                0.525695
# 18    effector memory CD8-positive, alpha-beta T cell                0.480984
# 19                        plasmacytoid dendritic cell                0.399691
# 20                                           platelet                0.398336
# 21                                        plasma cell                0.233040
# 22                       hematopoietic precursor cell                0.195103
# 23                                   mature NK T cell                0.096197
# 24                               innate lymphoid cell                0.084003
# 25                                        erythrocyte                0.077228
# 26                                     dendritic cell                0.020323
# 27                                        plasmablast                0.018968
# 28                                        granulocyte                0.001355
#
#     Recall Base  Recall cellFlow  Recall scDiffusion  Recall scVI
# 0      0.873984         0.885553            0.884369     0.900619
# 1      0.980258         0.959537            0.975037     0.973079
# 2      0.913009         0.860496            0.901870     0.898687
# 3      0.804895         0.714446            0.778309     0.723168
# 4      0.825031         0.830791            0.826743     0.794988
# 5      0.958104         0.973443            0.957875     0.983745
# 6      0.776026         0.661865            0.796140     0.784452
# 7      0.948802         0.969136            0.956790     0.952070
# 8      0.451693         0.333167            0.477590     0.347610
# 9      0.276316         0.367225            0.323565     0.284689
# 10     0.786055         0.825215            0.777459     0.748806
# 11     0.655443         0.712682            0.689113     0.579125
# 12     0.491429         0.598857            0.490286     0.523429
# 13     0.212051         0.251448            0.142526     0.132097
# 14     0.511025         0.726329            0.596628     0.468223
# 15     0.205776         0.404332            0.200361     0.093863
# 16     0.692593         0.703704            0.670370     0.637037
# 17     0.059278         0.128866            0.061856     0.030928
# 18     0.101408         0.222535            0.123944     0.112676
# 19     0.996610         1.000000            0.996610     0.993220
# 20     1.000000         0.996599            1.000000     1.000000
# 21     0.970930         0.895349            0.953488     0.959302
# 22     0.965278         0.875000            0.965278     0.958333
# 23     0.000000         0.056338            0.000000     0.000000
# 24     0.209677         0.387097            0.177419     0.112903
# 25     1.000000         1.000000            1.000000     1.000000
# 26     0.466667         0.666667            0.466667     0.466667
# 27     0.928571         1.000000            0.928571     0.928571
# 28     1.000000         1.000000            1.000000     1.000000

# %%
results['Recall Base'].mean(0)
# Out:
# 0.6572727874808921

# %%
results['Recall cellFlow'].mean(0)
# Out:
# 0.689885408781313

# %%
results['Recall scDiffusion'].mean(0)
# Out:
# 0.6592712107546812

# %%
results['Recall scVI'].mean(0)
# Out:
# 0.6340788573542065
