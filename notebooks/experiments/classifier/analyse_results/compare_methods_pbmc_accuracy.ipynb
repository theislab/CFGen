# %%
import pandas as pd

# %%
data_non_aug = """classical monocyte: 0.980257790830478
CD4-positive helper T cell: 0.8108032072021382
naive thymus-derived CD8-positive, alpha-beta T cell: 0.7856475716064757
naive thymus-derived CD4-positive, alpha-beta T cell: 0.8891579230562281
CD16-negative, CD56-bright natural killer cell, human: 0.6554433221099888
natural killer cell: 0.9143349688370243
gamma-delta T cell: 0.5611428571428572
naive B cell: 0.9585622710622711
non-classical monocyte: 0.9491648511256354
central memory CD8-positive, alpha-beta T cell: 0.45766932270916333
conventional dendritic cell: 0.7860553963705826
CD8-positive, alpha-beta cytotoxic T cell: 0.789616743680348
regulatory T cell: 0.2805023923444976
class switched memory B cell: 0.5058365758754864
CD4-positive, alpha-beta cytotoxic T cell: 0.03608247422680412
effector memory CD8-positive, alpha-beta T cell, terminally differentiated: 0.13904982618771727
platelet: 1.0
effector memory CD8-positive, alpha-beta T cell: 0.10704225352112676
mucosal invariant T cell: 0.6148148148148148
plasmacytoid dendritic cell: 0.9966101694915255
innate lymphoid cell: 0.20967741935483872
B cell: 0.20577617328519857
plasmablast: 0.9285714285714286
plasma cell: 0.9767441860465116
hematopoietic precursor cell: 0.9652777777777778
dendritic cell: 0.4666666666666667
mature NK T cell: 0.0
erythrocyte: 1.0
granulocyte: 1.0"""

# %%
data_aug_cellflow = """classical monocyte: 0.9615761135584924
CD4-positive helper T cell: 0.756646504431003
naive thymus-derived CD8-positive, alpha-beta T cell: 0.7907845579078456
naive thymus-derived CD4-positive, alpha-beta T cell: 0.8987893462469734
CD16-negative, CD56-bright natural killer cell, human: 0.7160493827160493
natural killer cell: 0.8526720594085665
gamma-delta T cell: 0.5977142857142858
naive B cell: 0.9764194139194139
non-classical monocyte: 0.966957153231663
central memory CD8-positive, alpha-beta T cell: 0.3256972111553785
conventional dendritic cell: 0.8452722063037249
CD8-positive, alpha-beta cytotoxic T cell: 0.6648545800489264
regulatory T cell: 0.32595693779904306
class switched memory B cell: 0.7185473411154345
CD4-positive, alpha-beta cytotoxic T cell: 0.12886597938144329
effector memory CD8-positive, alpha-beta T cell, terminally differentiated: 0.272305909617613
platelet: 0.9965986394557823
effector memory CD8-positive, alpha-beta T cell: 0.2507042253521127
mucosal invariant T cell: 0.6685185185185185
plasmacytoid dendritic cell: 1.0
innate lymphoid cell: 0.4032258064516129
B cell: 0.3916967509025271
plasmablast: 1.0
plasma cell: 0.9011627906976745
hematopoietic precursor cell: 0.8819444444444444
dendritic cell: 0.7333333333333333
mature NK T cell: 0.056338028169014086
erythrocyte: 1.0
granulocyte: 1.0"""

# %%
data_aug_scdiffusion = """classical monocyte: 0.9750367107195301
CD4-positive helper T cell: 0.778309185539457
naive thymus-derived CD8-positive, alpha-beta T cell: 0.8267434620174346
naive thymus-derived CD4-positive, alpha-beta T cell: 0.8843691148775894
CD16-negative, CD56-bright natural killer cell, human: 0.6891133557800224
natural killer cell: 0.9018697785439597
gamma-delta T cell: 0.49028571428571427
naive B cell: 0.9578754578754579
non-classical monocyte: 0.9567901234567902
central memory CD8-positive, alpha-beta T cell: 0.47758964143426297
conventional dendritic cell: 0.7774594078319007
CD8-positive, alpha-beta cytotoxic T cell: 0.7961402555042131
regulatory T cell: 0.3235645933014354
class switched memory B cell: 0.5966277561608301
CD4-positive, alpha-beta cytotoxic T cell: 0.061855670103092786
effector memory CD8-positive, alpha-beta T cell, terminally differentiated: 0.1425260718424102
platelet: 1.0
effector memory CD8-positive, alpha-beta T cell: 0.12394366197183099
mucosal invariant T cell: 0.6703703703703704
plasmacytoid dendritic cell: 0.9966101694915255
innate lymphoid cell: 0.1774193548387097
B cell: 0.2003610108303249
plasmablast: 0.9285714285714286
plasma cell: 0.9534883720930233
hematopoietic precursor cell: 0.9652777777777778
dendritic cell: 0.4666666666666667
mature NK T cell: 0.0
erythrocyte: 1.0
granulocyte: 1.0"""

# %%
data_aug_scvi="""classical monocyte: 0.9730788056779246
CD4-positive helper T cell: 0.7254184836123224
naive thymus-derived CD8-positive, alpha-beta T cell: 0.7965442092154421
naive thymus-derived CD4-positive, alpha-beta T cell: 0.8930858218993812
CD16-negative, CD56-bright natural killer cell, human: 0.5836139169472503
natural killer cell: 0.9016045617292137
gamma-delta T cell: 0.49142857142857144
naive B cell: 0.9828296703296703
non-classical monocyte: 0.9549745824255628
central memory CD8-positive, alpha-beta T cell: 0.36703187250996017
conventional dendritic cell: 0.7478510028653295
CD8-positive, alpha-beta cytotoxic T cell: 0.778744223973906
regulatory T cell: 0.3008373205741627
class switched memory B cell: 0.4669260700389105
CD4-positive, alpha-beta cytotoxic T cell: 0.05154639175257732
effector memory CD8-positive, alpha-beta T cell, terminally differentiated: 0.11703360370799537
platelet: 0.9965986394557823
effector memory CD8-positive, alpha-beta T cell: 0.1352112676056338
mucosal invariant T cell: 0.6407407407407407
plasmacytoid dendritic cell: 0.9932203389830508
innate lymphoid cell: 0.16129032258064516
B cell: 0.09205776173285199
plasmablast: 0.9285714285714286
plasma cell: 0.9593023255813954
hematopoietic precursor cell: 0.9513888888888888
dendritic cell: 0.4
mature NK T cell: 0.0
erythrocyte: 1.0
granulocyte: 1.0"""

# %%
# Create a dictionary to store the cell types and their accuracies
acc_non_aug = {}

# Process each line in the data string
for line in data_non_aug.strip().split('\n'):
    # Split each line into cell type and accuracy based on the colon separator
    cell_type, accuracy = line.split(':')
    # Trim whitespace and convert accuracy to float, then store in dictionary
    acc_non_aug[cell_type.strip()] = float(accuracy.strip())

# Now the dictionary `cell_type_accuracy` has all the cell types as keys and their accuracies as values
for k in acc_non_aug.keys():
    print(k)
    print(acc_non_aug[k])
# Out:
# classical monocyte
# 0.980257790830478
# CD4-positive helper T cell
# 0.8108032072021382
# naive thymus-derived CD8-positive, alpha-beta T cell
# 0.7856475716064757
# naive thymus-derived CD4-positive, alpha-beta T cell
# 0.8891579230562281
# CD16-negative, CD56-bright natural killer cell, human
# 0.6554433221099888
# natural killer cell
# 0.9143349688370243
# gamma-delta T cell
# 0.5611428571428572
# naive B cell
# 0.9585622710622711
# non-classical monocyte
# 0.9491648511256354
# central memory CD8-positive, alpha-beta T cell
# 0.45766932270916333
# conventional dendritic cell
# 0.7860553963705826
# CD8-positive, alpha-beta cytotoxic T cell
# 0.789616743680348
# regulatory T cell
# 0.2805023923444976
# class switched memory B cell
# 0.5058365758754864
# CD4-positive, alpha-beta cytotoxic T cell
# 0.03608247422680412
# effector memory CD8-positive, alpha-beta T cell, terminally differentiated
# 0.13904982618771727
# platelet
# 1.0
# effector memory CD8-positive, alpha-beta T cell
# ...

# %%
# Create a dictionary to store the cell types and their accuracies
acc_aug_cellflow = {}

# Process each line in the data string
for line in data_aug_cellflow.strip().split('\n'):
    # Split each line into cell type and accuracy based on the colon separator
    cell_type, accuracy = line.split(':')
    # Trim whitespace and convert accuracy to float, then store in dictionary
    acc_aug_cellflow[cell_type.strip()] = float(accuracy.strip())

# %%
# Create a dictionary to store the cell types and their accuracies
acc_aug_scdiffusion = {}

# Process each line in the data string
for line in data_aug_scdiffusion.strip().split('\n'):
    # Split each line into cell type and accuracy based on the colon separator
    cell_type, accuracy = line.split(':')
    # Trim whitespace and convert accuracy to float, then store in dictionary
    acc_aug_scdiffusion[cell_type.strip()] = float(accuracy.strip())

# %%
# Create a dictionary to store the cell types and their accuracies
acc_aug_scvi = {}

# Process each line in the data string
for line in data_aug_scvi.strip().split('\n'):
    # Split each line into cell type and accuracy based on the colon separator
    cell_type, accuracy = line.split(':')
    # Trim whitespace and convert accuracy to float, then store in dictionary
    acc_aug_scvi[cell_type.strip()] = float(accuracy.strip())

# %% [markdown]
# Create data frame

# %%
results = pd.read_csv("/home/icb/alessandro.palma/environment/cfgen/project_folder/classification_experiments/hanyi_celldreamer/classifier/scGPT/scGPT_results.csv")

# %%
results.columns = ["Cell Type",
                   "Relative Frequency (%)",
                   "Accuracy Base", 
                   "Accuracy cellFlow", 
                  ]
results
# Out:
#                                             Cell Type  Relative Frequency (%)  \
# 0   naive thymus-derived CD4-positive, alpha-beta ...               25.180538
# 1                                  classical monocyte               16.608181
# 2                                 natural killer cell               10.217188
# 3                          CD4-positive helper T cell                9.631878
# 4   naive thymus-derived CD8-positive, alpha-beta ...                8.703781
# 5                                        naive B cell                5.918138
# 6           CD8-positive, alpha-beta cytotoxic T cell                4.984622
# 7                              non-classical monocyte                3.731353
# 8      central memory CD8-positive, alpha-beta T cell                2.720609
# 9                                   regulatory T cell                2.265368
# 10                        conventional dendritic cell                1.418565
# ...

# %%
results["Accuracy scDiffusion"] = 0
results["Accuracy scVI"] = 0

# %%
for index, row in results.iterrows():
    cell_type = row['Cell Type']
    results.at[index, 'Accuracy Base'] = acc_non_aug[cell_type]
    results.at[index, 'Accuracy cellFlow'] = acc_aug_cellflow[cell_type]
    results.at[index, 'Accuracy scDiffusion'] = acc_aug_scdiffusion[cell_type]
    results.at[index, 'Accuracy scVI'] = acc_aug_scvi[cell_type]
# Out:
# /var/tmp/ipykernel_2999446/1657181760.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.8843691148775894' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   results.at[index, 'Accuracy scDiffusion'] = acc_aug_scdiffusion[cell_type]
# /var/tmp/ipykernel_2999446/1657181760.py:6: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.8930858218993812' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   results.at[index, 'Accuracy scVI'] = acc_aug_scvi[cell_type]

# %%
results.to_csv("pbmc_method_comparison.csv")

# %%
results["Accuracy Base"].mean(0)
# Out:
# 0.6541554615137097

# %%
results["Accuracy cellFlow"].mean(0)
# Out:
# 0.6925045351683061

# %%
results["Accuracy scDiffusion"].mean(0)
# Out:
# 0.6592712107546812

# %%
results["Accuracy scVI"].mean(0)
# Out:
# 0.6341700283733999
