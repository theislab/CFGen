capillary endothelial cell: 0.8973463687150838
vein endothelial cell: 0.9494147157190636
CD8-positive, alpha-beta T cell: 0.8775857554333595
alveolar type 1 fibroblast cell: 0.8275862068965517
club cell: 0.5539243365330322
endothelial cell of lymphatic vessel: 0.9075182967398536
type I pneumocyte: 0.9411089866156788
lung macrophage: 0.3948434622467772
multi-ciliated epithelial cell: 0.5474576271186441
alveolar type 2 fibroblast cell: 0.9238385376999239
CD1c-positive myeloid dendritic cell: 0.738395225464191
epithelial cell of lower respiratory tract: 0.8882758620689655
tracheobronchial serous cell: 0.38961038961038963
mast cell: 0.9506903353057199
myofibroblast cell: 0.5074626865671642
B cell: 0.8768619662363456
bronchial goblet cell: 0.03899721448467967
respiratory hillock cell: 0.7716666666666666
lung pericyte: 0.8881578947368421
epithelial cell of alveolus of lung: 0.15555555555555556
plasmacytoid dendritic cell: 0.935251798561151
tracheobronchial smooth muscle cell: 0.7655038759689923
plasma cell: 0.9757575757575757
T cell: 0.6194029850746269
smooth muscle cell: 0.11764705882352941
acinar cell: 0.6764705882352942
lung neuroendocrine cell: 0.96875
ionocyte: 0.8214285714285714
mucus secreting cell: 0.6829268292682927
conventional dendritic cell: 0.6923076923076923
brush cell of trachebronchial tree: 0.5789473684210527
fibroblast: 0.7
stromal cell: 0.35294117647058826
dendritic cell: 0.5135135135135135
hematopoietic stem cell: 0.8888888888888888
mesothelial cell: 0.9428571428571428
tracheobronchial goblet cell: 0.25
serous secreting cell: 0.25"""

# %%
# Create a dictionary to store the cell types and their accuracies
acc_non_aug = {}

# Process each line in the data string
for line in data_non_aug.strip().split('\n'):
    # Split each line into cell type and accuracy based on the colon separator
    cell_type, accuracy = line.split(':')
    # Trim whitespace and convert accuracy to float, then store in dictionary
    acc_non_aug[cell_type.strip()] = float(accuracy.strip())

# Now the dictionary `cell_type_accuracy` has all the cell types as keys and their accuracies as values
for k in acc_non_aug.keys():
    print(k)
    print(acc_non_aug[k])
# Out:
# alveolar macrophage
# 0.9540674795174505
# bronchus fibroblast of lung
# 0.6836065573770492
# respiratory basal cell
# 0.9151035049697333
# type II pneumocyte
# 0.9893012370444667
# ciliated columnar cell of tracheobronchial tree
# 0.9660771238040011
# nasal mucosa goblet cell
# 0.8742130894405511
# CD4-positive, alpha-beta T cell
# 0.5811676082862524
# classical monocyte
# 0.8727417640807651
# elicited macrophage
# 0.696514012303486
# pulmonary artery endothelial cell
# 0.6936905181529786
# non-classical monocyte
# 0.5426511814177012
# natural killer cell
# 0.8135158254918734
# capillary endothelial cell
# 0.9152700186219739
# vein endothelial cell
# 0.9335284280936454
# CD8-positive, alpha-beta T cell
# 0.8968316313170988
# alveolar type 1 fibroblast cell
# 0.8169761273209549
# club cell
# 0.6119424054206662
# endothelial cell of lymphatic vessel
# 0.9208250166333999
# type I pneumocyte
# 0.9376673040152964
# lung macrophage
# 0.3572744014732965
# multi-ciliated epithelial cell
# ...

# %%
# Create a dictionary to store the cell types and their accuracies
acc_aug_cellflow_std = {}

# Process each line in the data string
for line in data_aug_cellflow_std.strip().split('\n'):
    # Split each line into cell type and accuracy based on the colon separator
    cell_type, accuracy = line.split(':')
    # Trim whitespace and convert accuracy to float, then store in dictionary
    acc_aug_cellflow_std[cell_type.strip()] = float(accuracy.strip())

# %%
# Create a dictionary to store the cell types and their accuracies
acc_aug_cellflow_std = {}

# Process each line in the data string
for line in data_aug_cellflow_std.strip().split('\n'):
    # Split each line into cell type and accuracy based on the colon separator
    cell_type, accuracy = line.split(':')
    # Trim whitespace and convert accuracy to float, then store in dictionary
    acc_aug_cellflow_std[cell_type.strip()] = float(accuracy.strip())

# %%
# Create a dictionary to store the cell types and their accuracies
acc_aug_cellflow_less_100000 = {}

# Process each line in the data string
for line in data_aug_cellflow_less_100000.strip().split('\n'):
    # Split each line into cell type and accuracy based on the colon separator
    cell_type, accuracy = line.split(':')
    # Trim whitespace and convert accuracy to float, then store in dictionary
    acc_aug_cellflow_less_100000[cell_type.strip()] = float(accuracy.strip())

# %%
# Create a dictionary to store the cell types and their accuracies
acc_aug_cellflow_less_10000 = {}

# Process each line in the data string
for line in data_aug_cellflow_less_10000.strip().split('\n'):
    # Split each line into cell type and accuracy based on the colon separator
    cell_type, accuracy = line.split(':')
    # Trim whitespace and convert accuracy to float, then store in dictionary
    acc_aug_cellflow_less_10000[cell_type.strip()] = float(accuracy.strip())

# %%
# Create a dictionary to store the cell types and their accuracies
acc_aug_cellflow_less_1000 = {}

# Process each line in the data string
for line in data_aug_cellflow_less_1000.strip().split('\n'):
    # Split each line into cell type and accuracy based on the colon separator
    cell_type, accuracy = line.split(':')
    # Trim whitespace and convert accuracy to float, then store in dictionary
    acc_aug_cellflow_less_1000[cell_type.strip()] = float(accuracy.strip())

# %%
# Create a dictionary to store the cell types and their accuracies
acc_aug_cellflow_rare_5000 = {}

# Process each line in the data string
for line in data_aug_cellflow_rare_5000.strip().split('\n'):
    # Split each line into cell type and accuracy based on the colon separator
    cell_type, accuracy = line.split(':')
    # Trim whitespace and convert accuracy to float, then store in dictionary
    acc_aug_cellflow_rare_5000[cell_type.strip()] = float(accuracy.strip())

# %%
# Create a dictionary to store the cell types and their accuracies
acc_aug_cellflow_rare_1000 = {}

# Process each line in the data string
for line in data_aug_cellflow_rare_1000.strip().split('\n'):
    # Split each line into cell type and accuracy based on the colon separator
    cell_type, accuracy = line.split(':')
    # Trim whitespace and convert accuracy to float, then store in dictionary
    acc_aug_cellflow_rare_1000[cell_type.strip()] = float(accuracy.strip())

# %% [markdown]
# Create data frame

# %%
results = pd.read_csv("/home/icb/alessandro.palma/environment/cfgen/project_folder/classification_experiments/hanyi_celldreamer/classifier/scGPT/scGPT_results_hlca.csv")

# %%
results.columns = ["Cell Type",
                   "Relative Frequency (%)",
                   "Accuracy Base", 
                   "Accuracy cellFlow std", 
                  ]
results
# Out:
#                                           Cell Type  Relative Frequency (%)  \
# 0                               alveolar macrophage               19.997936
# 1                                type II pneumocyte               13.505477
# 2                            respiratory basal cell                8.631455
# 3   ciliated columnar cell of tracheobronchial tree                6.674364
# 4                          nasal mucosa goblet cell                5.430702
# 5                   CD8-positive, alpha-beta T cell                4.926915
# 6                                         club cell                4.569556
# 7                               elicited macrophage                3.774851
# 8                   CD4-positive, alpha-beta T cell                3.425232
# 9                             vein endothelial cell                3.085934
# 10                       capillary endothelial cell                2.771148
# ...

# %%
results["Accuracy cellFlow 100000"] = 0
results["Accuracy cellFlow 10000"] = 0
results["Accuracy cellFlow 1000"] = 0
results["Accuracy cellFlow rare 5000"] = 0
results["Accuracy cellFlow rare 1000"] = 0

# %%
for index, row in results.iterrows():
    cell_type = row['Cell Type']
    results.at[index, 'Accuracy Base'] = acc_non_aug[cell_type]
    results.at[index, 'Accuracy cellFlow std'] = acc_aug_cellflow_std[cell_type]
    results.at[index, 'Accuracy cellFlow 100000'] = acc_aug_cellflow_less_100000[cell_type]
    results.at[index, 'Accuracy cellFlow 10000'] = acc_aug_cellflow_less_10000[cell_type]
    results.at[index, 'Accuracy cellFlow 1000'] = acc_aug_cellflow_less_1000[cell_type]
    results.at[index, 'Accuracy cellFlow rare 5000'] = acc_aug_cellflow_rare_5000[cell_type]
    results.at[index, 'Accuracy cellFlow rare 1000'] = acc_aug_cellflow_rare_1000[cell_type]
# Out:
# /var/tmp/ipykernel_2550638/3887792134.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.952261144442294' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   results.at[index, 'Accuracy cellFlow 100000'] = acc_aug_cellflow_less_100000[cell_type]
# /var/tmp/ipykernel_2550638/3887792134.py:6: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.9532288239468422' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   results.at[index, 'Accuracy cellFlow 10000'] = acc_aug_cellflow_less_10000[cell_type]
# /var/tmp/ipykernel_2550638/3887792134.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.9528417521450229' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
# ...

# %%
results
# Out:
#                                           Cell Type  Relative Frequency (%)  \
# 0                               alveolar macrophage               19.997936
# 1                                type II pneumocyte               13.505477
# 2                            respiratory basal cell                8.631455
# 3   ciliated columnar cell of tracheobronchial tree                6.674364
# 4                          nasal mucosa goblet cell                5.430702
# 5                   CD8-positive, alpha-beta T cell                4.926915
# 6                                         club cell                4.569556
# 7                               elicited macrophage                3.774851
# 8                   CD4-positive, alpha-beta T cell                3.425232
# 9                             vein endothelial cell                3.085934
# 10                       capillary endothelial cell                2.771148
# ...
