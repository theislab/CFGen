lung pericyte: 0.9013157894736842
epithelial cell of alveolus of lung: 0.5155555555555555
plasmacytoid dendritic cell: 0.9532374100719424
tracheobronchial smooth muscle cell: 0.6686046511627907
plasma cell: 0.9842424242424243
T cell: 0.5970149253731343
smooth muscle cell: 0.11764705882352941
acinar cell: 0.8319327731092437
lung neuroendocrine cell: 0.96875
ionocyte: 0.8357142857142857
mucus secreting cell: 0.7317073170731707
conventional dendritic cell: 0.7538461538461538
brush cell of trachebronchial tree: 0.5263157894736842
fibroblast: 0.4
stromal cell: 0.8235294117647058
dendritic cell: 0.6756756756756757
hematopoietic stem cell: 1.0
mesothelial cell: 0.9714285714285714
tracheobronchial goblet cell: 0.5
serous secreting cell: 0.25"""

# %%
data_aug_cellflow_rare = """alveolar macrophage: 0.9521966324753242
bronchus fibroblast of lung: 0.7245901639344262
respiratory basal cell: 0.8742246468873777
type II pneumocyte: 0.9763098820270335
ciliated columnar cell of tracheobronchial tree: 0.845559099255823
nasal mucosa goblet cell: 0.8558023518232569
CD4-positive, alpha-beta T cell: 0.5858757062146893
classical monocyte: 0.8756641870350691
elicited macrophage: 0.6672932330827067
pulmonary artery endothelial cell: 0.8826224885442369
non-classical monocyte: 0.4897877452943532
natural killer cell: 0.8092386655260907
capillary endothelial cell: 0.667364990689013
vein endothelial cell: 0.8413461538461539
CD8-positive, alpha-beta T cell: 0.8893689447499346
alveolar type 1 fibroblast cell: 0.916445623342175
club cell: 0.5770750988142292
endothelial cell of lymphatic vessel: 0.9407850964737192
type I pneumocyte: 0.9380497131931166
lung macrophage: 0.6644567219152855
multi-ciliated epithelial cell: 0.752542372881356
alveolar type 2 fibroblast cell: 0.8088347296268088
CD1c-positive myeloid dendritic cell: 0.6372679045092838
epithelial cell of lower respiratory tract: 0.8972413793103449
tracheobronchial serous cell: 0.4935064935064935
mast cell: 0.9506903353057199
myofibroblast cell: 0.3283582089552239
B cell: 0.9364448857994042
bronchial goblet cell: 0.2785515320334262
respiratory hillock cell: 0.8783333333333333
lung pericyte: 0.8881578947368421
epithelial cell of alveolus of lung: 0.5111111111111111
plasmacytoid dendritic cell: 0.8920863309352518
tracheobronchial smooth muscle cell: 0.7751937984496124
plasma cell: 0.9818181818181818
T cell: 0.6492537313432836
smooth muscle cell: 0.029411764705882353
acinar cell: 0.7605042016806722
lung neuroendocrine cell: 0.96875
ionocyte: 0.8285714285714286
mucus secreting cell: 0.6097560975609756
conventional dendritic cell: 0.676923076923077
brush cell of trachebronchial tree: 0.3157894736842105
fibroblast: 0.3
stromal cell: 0.6470588235294118
dendritic cell: 0.5675675675675675
hematopoietic stem cell: 0.7777777777777778
mesothelial cell: 0.8857142857142857
tracheobronchial goblet cell: 0.375
serous secreting cell: 0.25"""

# %%
# Create a dictionary to store the cell types and their accuracies
acc_non_aug = {}

# Process each line in the data string
for line in data_non_aug.strip().split('\n'):
    # Split each line into cell type and accuracy based on the colon separator
    cell_type, accuracy = line.split(':')
    # Trim whitespace and convert accuracy to float, then store in dictionary
    acc_non_aug[cell_type.strip()] = float(accuracy.strip())

# Now the dictionary `cell_type_accuracy` has all the cell types as keys and their accuracies as values
for k in acc_non_aug.keys():
    print(k)
    print(acc_non_aug[k])
# Out:
# alveolar macrophage
# 0.9540674795174505
# bronchus fibroblast of lung
# 0.6836065573770492
# respiratory basal cell
# 0.9151035049697333
# type II pneumocyte
# 0.9893012370444667
# ciliated columnar cell of tracheobronchial tree
# 0.9660771238040011
# nasal mucosa goblet cell
# 0.8742130894405511
# CD4-positive, alpha-beta T cell
# 0.5811676082862524
# classical monocyte
# 0.8727417640807651
# elicited macrophage
# 0.696514012303486
# pulmonary artery endothelial cell
# 0.6936905181529786
# non-classical monocyte
# 0.5426511814177012
# natural killer cell
# 0.8135158254918734
# capillary endothelial cell
# 0.9152700186219739
# vein endothelial cell
# 0.9335284280936454
# CD8-positive, alpha-beta T cell
# 0.8968316313170988
# alveolar type 1 fibroblast cell
# 0.8169761273209549
# club cell
# 0.6119424054206662
# endothelial cell of lymphatic vessel
# 0.9208250166333999
# type I pneumocyte
# 0.9376673040152964
# lung macrophage
# 0.3572744014732965
# multi-ciliated epithelial cell
# ...

# %%
# Create a dictionary to store the cell types and their accuracies
acc_aug_cellflow_std = {}

# Process each line in the data string
for line in data_aug_cellflow_std.strip().split('\n'):
    # Split each line into cell type and accuracy based on the colon separator
    cell_type, accuracy = line.split(':')
    # Trim whitespace and convert accuracy to float, then store in dictionary
    acc_aug_cellflow_std[cell_type.strip()] = float(accuracy.strip())

# %%
# Create a dictionary to store the cell types and their accuracies
acc_aug_cellflow_std = {}

# Process each line in the data string
for line in data_aug_cellflow_std.strip().split('\n'):
    # Split each line into cell type and accuracy based on the colon separator
    cell_type, accuracy = line.split(':')
    # Trim whitespace and convert accuracy to float, then store in dictionary
    acc_aug_cellflow_std[cell_type.strip()] = float(accuracy.strip())

# %%
# Create a dictionary to store the cell types and their accuracies
acc_aug_cellflow_rare = {}

# Process each line in the data string
for line in data_aug_cellflow_rare.strip().split('\n'):
    # Split each line into cell type and accuracy based on the colon separator
    cell_type, accuracy = line.split(':')
    # Trim whitespace and convert accuracy to float, then store in dictionary
    acc_aug_cellflow_rare[cell_type.strip()] = float(accuracy.strip())

# %% [markdown]
# Create data frame

# %%
results = pd.read_csv("/home/icb/alessandro.palma/environment/cfgen/project_folder/classification_experiments/hanyi_celldreamer/classifier/scGPT/scGPT_results_hlca.csv")

# %%
results.columns = ["Cell Type",
                   "Relative Frequency (%)",
                   "Accuracy Base", 
                   "Accuracy cellFlow std", 
                  ]
results
# Out:
#                                           Cell Type  Relative Frequency (%)  \
# 0                               alveolar macrophage               19.997936
# 1                                type II pneumocyte               13.505477
# 2                            respiratory basal cell                8.631455
# 3   ciliated columnar cell of tracheobronchial tree                6.674364
# 4                          nasal mucosa goblet cell                5.430702
# 5                   CD8-positive, alpha-beta T cell                4.926915
# 6                                         club cell                4.569556
# 7                               elicited macrophage                3.774851
# 8                   CD4-positive, alpha-beta T cell                3.425232
# 9                             vein endothelial cell                3.085934
# 10                       capillary endothelial cell                2.771148
# ...

# %%
results["Accuracy cellFlow rare"] = 0

# %%
for index, row in results.iterrows():
    cell_type = row['Cell Type']
    results.at[index, 'Accuracy Base'] = acc_non_aug[cell_type]
    results.at[index, 'Accuracy cellFlow std'] = acc_aug_cellflow_std[cell_type]
    results.at[index, 'Accuracy cellFlow rare'] = acc_aug_cellflow_rare[cell_type]
# Out:
# /var/tmp/ipykernel_3085404/3725276656.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.9521966324753242' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   results.at[index, 'Accuracy cellFlow rare'] = acc_aug_cellflow_rare[cell_type]

# %%
results
# Out:
#                                           Cell Type  Relative Frequency (%)  \
# 0                               alveolar macrophage               19.997936
# 1                                type II pneumocyte               13.505477
# 2                            respiratory basal cell                8.631455
# 3   ciliated columnar cell of tracheobronchial tree                6.674364
# 4                          nasal mucosa goblet cell                5.430702
# 5                   CD8-positive, alpha-beta T cell                4.926915
# 6                                         club cell                4.569556
# 7                               elicited macrophage                3.774851
# 8                   CD4-positive, alpha-beta T cell                3.425232
# 9                             vein endothelial cell                3.085934
# 10                       capillary endothelial cell                2.771148
# ...

# %%
results["Accuracy Base"].mean(0)
# Out:
# 0.6750009461644286

# %%
results["Accuracy cellFlow std"].mean(0)
# Out:
# 0.7492584704899297

# %%
results["Accuracy cellFlow rare"].mean(0)
# Out:
# 0.7125254773298997

# %% [markdown]
# ## Percentage of dropped scores

# %%
((results["Accuracy cellFlow std"] - results["Accuracy Base"])<0).sum()/ 50
# Out:
# 0.26

# %%
((results["Accuracy cellFlow rare"] - results["Accuracy Base"])<0).sum()/ 50
# Out:
# 0.4
