# %%
import scanpy as sc
import numpy as np

# %%
adata_hlca = sc.read_h5ad("/home/icb/alessandro.palma/environment/cfgen/project_folder/datasets/processed_full_genome/hlca_core/hlca_core.h5ad")

# %%
adata_hlca.obs["size_factor"] = adata_hlca.layers["X_counts"].sum(1)

# %%
sc.pl.umap(adata_hlca, color=["study","size_factor"], )
# Out:
# /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.umap(adata_hlca[adata_hlca.obs["study"]=="Barbry_Leroy_2020"], color="size_factor", s=15, save="study1.png")
# Out:
# WARNING: saving figure to file figures/umapstudy1.png

# %%
sc.pl.umap(adata_hlca[adata_hlca.obs["study"]=="Jain_Misharin_2021"], color="size_factor", s=15, save="study2.png" )
# Out:
# WARNING: saving figure to file figures/umapstudy2.png

# %%
sc.pl.umap(adata_hlca[adata_hlca.obs["study"]=="Teichmann_Meyer_2019"], color="size_factor", s=15, save="study3.png" )
# Out:
# WARNING: saving figure to file figures/umapstudy3.png

# %%
sc.pl.umap(adata_hlca[adata_hlca.obs["study"]=="Seibold_2020"], color="size_factor", s=15, save="study4.png" )
# Out:
# WARNING: saving figure to file figures/umapstudy4.png

# %%
sc.pl.umap(adata_hlca[adata_hlca.obs["study"]=="Banovich_Kropski_2020"], color="size_factor", s=15, save="study5.png" )
# Out:
# WARNING: saving figure to file figures/umapstudy5.png

# %%
sc.pl.umap(adata_hlca[adata_hlca.obs["study"]=="Nawijn_2021"], color="size_factor", s=15, save="study6.png" )
# Out:
# WARNING: saving figure to file figures/umapstudy6.png

# %%
adata_hlca.obs["study"]Nawijn_2021
# Out:
# GCGACCATCCCTAACC_SC22      Misharin_Budinger_2018
# P2_1_GCGCAACCAGTTAACC                Krasnow_2020
# GCTCTGTAGTGCTGCC_SC27      Misharin_Budinger_2018
# P2_8_TTAGGACGTTCAGGCC                Krasnow_2020
# CTTGATTGTCAGTTTG_T164                Seibold_2020
#                                     ...
# ACCTTTACATTAACCG_T120                Seibold_2020
# CATTATCTCCATGAAC_F01639     Banovich_Kropski_2020
# AGGCCGTGTGTGACCC-SC56         Lafyatis_Rojas_2019
# CGATGGCAGCAGGCTA-1-2           Jain_Misharin_2021
# AATCGGTGTCGGCACT-1-4           Jain_Misharin_2021
# Name: study, Length: 584944, dtype: category
# Categories (11, object): ['Banovich_Kropski_2020', 'Barbry_Leroy_2020', 'Jain_Misharin_2021', 'Krasnow_2020', ..., 'Misharin_Budinger_2018', 'Nawijn_2021', 'Seibold_2020', 'Teichmann_Meyer_2019']
