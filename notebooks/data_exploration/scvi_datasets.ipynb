# %%
import scvi
from celldreamer.paths import DATA_DIR
import scanpy as sc
import numpy as np
import seaborn as sns
import pandas as pd
# Out:
# /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages/scvi/_settings.py:63: UserWarning: Since v1.0.0, scvi-tools no longer uses a random seed by default. Run `scvi.settings.seed = 0` to reproduce results from previous versions.
#   self.seed = seed
# /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages/scvi/_settings.py:70: UserWarning: Setting `dl_pin_memory_gpu_training` is deprecated in v1.0 and will be removed in v1.1. Please pass in `pin_memory` to the data loaders instead.
#   self.dl_pin_memory_gpu_training = (

# %%
adata = sc.datasets.pbmc3k_processed()
# Out:
#   0%|          | 0.00/23.5M [00:00<?, ?B/s]

# %%
adata = sc.datasets.pbmc68k()

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 2638 × 1838
#     obs: 'n_genes', 'percent_mito', 'n_counts', 'louvain'
#     var: 'n_cells'
#     uns: 'draw_graph', 'louvain', 'louvain_colors', 'neighbors', 'pca', 'rank_genes_groups'
#     obsm: 'X_pca', 'X_tsne', 'X_umap', 'X_draw_graph_fr'
#     varm: 'PCs'
#     obsp: 'distances', 'connectivities'

# %%
sc.pl.umap(adata, color="louvain")
# Out:
# /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
# plt.scatter(adata.X.A.mean(1), adata.X.A.var(1))
sns.regplot(x="mean", y="var", data=pd.DataFrame({"mean":adata.X.mean(0), 
                                                 "var": adata.X.std(0)}));

# %%
pip install scvi-tools
# Out:
# Collecting scvi-tools
#   Downloading scvi_tools-1.0.0-py3-none-any.whl (351 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 351.0/351.0 kB 10.5 MB/s eta 0:00:00
# Requirement already satisfied: anndata>=0.7.5 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from scvi-tools) (0.9.1)
# Collecting chex (from scvi-tools)
#   Downloading chex-0.1.7-py3-none-any.whl (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.6/89.6 kB 15.4 MB/s eta 0:00:00
# Collecting docrep>=0.3.2 (from scvi-tools)
#   Using cached docrep-0.3.2.tar.gz (33 kB)
#   Preparing metadata (setup.py) ... done
# Collecting flax (from scvi-tools)
#   Downloading flax-0.6.10-py3-none-any.whl (226 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.1/226.1 kB 36.4 MB/s eta 0:00:00
# Requirement already satisfied: h5py>=2.9.0 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from scvi-tools) (3.8.0)
# Collecting jax>=0.4.4 (from scvi-tools)
#   Downloading jax-0.4.12.tar.gz (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 63.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting jaxlib>=0.4.3 (from scvi-tools)
#   Downloading jaxlib-0.4.12-cp310-cp310-manylinux2014_x86_64.whl (71.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.4/71.4 MB 39.7 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting lightning<2.1,>=2.0 (from scvi-tools)
#   Downloading lightning-2.0.3-py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 101.7 MB/s eta 0:00:00
# Collecting ml-collections>=0.1.1 (from scvi-tools)
#   Downloading ml_collections-0.1.1.tar.gz (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 11.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting mudata>=0.1.2 (from scvi-tools)
#   Downloading mudata-0.2.3-py3-none-any.whl (24 kB)
# Requirement already satisfied: numpy>=1.17.0 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from scvi-tools) (1.24.3)
# Collecting numpyro>=0.12.1 (from scvi-tools)
#   Downloading numpyro-0.12.1-py3-none-any.whl (304 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.6/304.6 kB 45.9 MB/s eta 0:00:00
# Collecting optax (from scvi-tools)
#   Downloading optax-0.1.5-py3-none-any.whl (164 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.6/164.6 kB 26.8 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.0 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from scvi-tools) (2.0.2)
# Collecting pyro-ppl>=1.6.0 (from scvi-tools)
#   Downloading pyro_ppl-1.8.5-py3-none-any.whl (732 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 732.5/732.5 kB 25.0 MB/s eta 0:00:00
# Collecting rich>=12.0.0 (from scvi-tools)
#   Downloading rich-13.4.2-py3-none-any.whl (239 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.4/239.4 kB 36.3 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=0.21.2 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from scvi-tools) (1.2.2)
# Requirement already satisfied: scipy in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from scvi-tools) (1.10.1)
# Collecting sparse>=0.14.0 (from scvi-tools)
#   Downloading sparse-0.14.0-py2.py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.0/81.0 kB 10.0 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.8.0 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from scvi-tools) (2.0.1)
# Requirement already satisfied: torchmetrics>=0.11.0 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from scvi-tools) (0.11.4)
# Requirement already satisfied: tqdm>=4.56.0 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from scvi-tools) (4.65.0)
# Requirement already satisfied: xarray>=2023.2.0 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from scvi-tools) (2023.5.0)
# Requirement already satisfied: natsort in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from anndata>=0.7.5->scvi-tools) (8.3.1)
# Requirement already satisfied: packaging>=20 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from anndata>=0.7.5->scvi-tools) (23.1)
# Requirement already satisfied: six in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from docrep>=0.3.2->scvi-tools) (1.16.0)
# Collecting ml-dtypes>=0.1.0 (from jax>=0.4.4->scvi-tools)
#   Downloading ml_dtypes-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 94.6 MB/s eta 0:00:00
# Collecting opt-einsum (from jax>=0.4.4->scvi-tools)
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Requirement already satisfied: Jinja2<5.0 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from lightning<2.1,>=2.0->scvi-tools) (3.1.2)
# Requirement already satisfied: PyYAML<8.0 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from lightning<2.1,>=2.0->scvi-tools) (6.0)
# Requirement already satisfied: arrow<3.0,>=1.2.0 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from lightning<2.1,>=2.0->scvi-tools) (1.2.3)
# Requirement already satisfied: beautifulsoup4<6.0,>=4.8.0 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from lightning<2.1,>=2.0->scvi-tools) (4.12.2)
# Requirement already satisfied: click<10.0 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from lightning<2.1,>=2.0->scvi-tools) (8.1.3)
# Collecting croniter<1.4.0,>=1.3.0 (from lightning<2.1,>=2.0->scvi-tools)
#   Downloading croniter-1.3.15-py2.py3-none-any.whl (19 kB)
# Collecting dateutils<2.0 (from lightning<2.1,>=2.0->scvi-tools)
#   Downloading dateutils-0.6.12-py2.py3-none-any.whl (5.7 kB)
# Collecting deepdiff<8.0,>=5.7.0 (from lightning<2.1,>=2.0->scvi-tools)
#   Downloading deepdiff-6.3.0-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.7/69.7 kB 11.6 MB/s eta 0:00:00
# Collecting fastapi<0.89.0,>=0.69.0 (from lightning<2.1,>=2.0->scvi-tools)
#   Downloading fastapi-0.88.0-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: fsspec<2024.0,>=2022.5.0 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from lightning<2.1,>=2.0->scvi-tools) (2023.5.0)
# Collecting inquirer<5.0,>=2.10.0 (from lightning<2.1,>=2.0->scvi-tools)
#   Downloading inquirer-3.1.3-py3-none-any.whl (18 kB)
# Collecting lightning-cloud>=0.5.34 (from lightning<2.1,>=2.0->scvi-tools)
#   Downloading lightning_cloud-0.5.36-py3-none-any.whl (562 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 562.4/562.4 kB 55.0 MB/s eta 0:00:00
# Requirement already satisfied: lightning-utilities<2.0,>=0.7.0 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from lightning<2.1,>=2.0->scvi-tools) (0.8.0)
# Requirement already satisfied: psutil<7.0 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from lightning<2.1,>=2.0->scvi-tools) (5.9.5)
# Collecting pydantic<4.0,>=1.7.4 (from lightning<2.1,>=2.0->scvi-tools)
#   Downloading pydantic-1.10.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 110.3 MB/s eta 0:00:00
# Collecting python-multipart<2.0,>=0.0.5 (from lightning<2.1,>=2.0->scvi-tools)
#   Downloading python_multipart-0.0.6-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 6.7 MB/s eta 0:00:00
# Requirement already satisfied: requests<4.0 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from lightning<2.1,>=2.0->scvi-tools) (2.31.0)
# Collecting starlette (from lightning<2.1,>=2.0->scvi-tools)
#   Downloading starlette-0.28.0-py3-none-any.whl (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.9/68.9 kB 10.8 MB/s eta 0:00:00
# Collecting starsessions<2.0,>=1.2.1 (from lightning<2.1,>=2.0->scvi-tools)
#   Downloading starsessions-1.3.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: traitlets<7.0,>=5.3.0 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from lightning<2.1,>=2.0->scvi-tools) (5.9.0)
# Requirement already satisfied: typing-extensions<6.0,>=4.0.0 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from lightning<2.1,>=2.0->scvi-tools) (4.6.3)
# Requirement already satisfied: urllib3<3.0 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from lightning<2.1,>=2.0->scvi-tools) (1.26.16)
# Collecting uvicorn<2.0 (from lightning<2.1,>=2.0->scvi-tools)
#   Downloading uvicorn-0.22.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.2 MB/s eta 0:00:00
# Requirement already satisfied: websocket-client<3.0 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from lightning<2.1,>=2.0->scvi-tools) (1.5.2)
# Collecting websockets<12.0 (from lightning<2.1,>=2.0->scvi-tools)
#   Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 22.9 MB/s eta 0:00:00
# Requirement already satisfied: pytorch-lightning in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from lightning<2.1,>=2.0->scvi-tools) (2.0.2)
# Requirement already satisfied: absl-py in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from ml-collections>=0.1.1->scvi-tools) (1.4.0)
# Collecting contextlib2 (from ml-collections>=0.1.1->scvi-tools)
#   Downloading contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Collecting multipledispatch (from numpyro>=0.12.1->scvi-tools)
#   Downloading multipledispatch-0.6.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from pandas>=1.0->scvi-tools) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from pandas>=1.0->scvi-tools) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from pandas>=1.0->scvi-tools) (2023.3)
# Collecting pyro-api>=0.1.1 (from pyro-ppl>=1.6.0->scvi-tools)
#   Downloading pyro_api-0.1.2-py3-none-any.whl (11 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=12.0.0->scvi-tools)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 12.9 MB/s eta 0:00:00
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from rich>=12.0.0->scvi-tools) (2.15.1)
# Requirement already satisfied: joblib>=1.1.1 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from scikit-learn>=0.21.2->scvi-tools) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from scikit-learn>=0.21.2->scvi-tools) (3.1.0)
# Requirement already satisfied: numba>=0.49 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from sparse>=0.14.0->scvi-tools) (0.57.0)
# Requirement already satisfied: filelock in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from torch>=1.8.0->scvi-tools) (3.12.0)
# Requirement already satisfied: sympy in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from torch>=1.8.0->scvi-tools) (1.12)
# Requirement already satisfied: networkx in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from torch>=1.8.0->scvi-tools) (3.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from torch>=1.8.0->scvi-tools) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from torch>=1.8.0->scvi-tools) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from torch>=1.8.0->scvi-tools) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from torch>=1.8.0->scvi-tools) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from torch>=1.8.0->scvi-tools) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from torch>=1.8.0->scvi-tools) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from torch>=1.8.0->scvi-tools) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from torch>=1.8.0->scvi-tools) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from torch>=1.8.0->scvi-tools) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from torch>=1.8.0->scvi-tools) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from torch>=1.8.0->scvi-tools) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from torch>=1.8.0->scvi-tools) (2.0.0)
# Requirement already satisfied: setuptools in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.8.0->scvi-tools) (67.8.0)
# Requirement already satisfied: wheel in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.8.0->scvi-tools) (0.40.0)
# Requirement already satisfied: cmake in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from triton==2.0.0->torch>=1.8.0->scvi-tools) (3.26.3)
# Requirement already satisfied: lit in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from triton==2.0.0->torch>=1.8.0->scvi-tools) (16.0.5)
# Collecting dm-tree>=0.1.5 (from chex->scvi-tools)
#   Downloading dm_tree-0.1.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (152 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.8/152.8 kB 22.6 MB/s eta 0:00:00
# Collecting toolz>=0.9.0 (from chex->scvi-tools)
#   Using cached toolz-0.12.0-py3-none-any.whl (55 kB)
# Collecting msgpack (from flax->scvi-tools)
#   Downloading msgpack-1.0.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (316 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.8/316.8 kB 43.3 MB/s eta 0:00:00
# Collecting orbax-checkpoint (from flax->scvi-tools)
#   Downloading orbax_checkpoint-0.2.5-py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.9/82.9 kB 11.3 MB/s eta 0:00:00
# Collecting tensorstore (from flax->scvi-tools)
#   Downloading tensorstore-0.1.37-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 126.9 MB/s eta 0:00:00m eta 0:00:010:01
# Requirement already satisfied: soupsieve>1.2 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from beautifulsoup4<6.0,>=4.8.0->lightning<2.1,>=2.0->scvi-tools) (2.4.1)
# Collecting ordered-set<4.2.0,>=4.0.2 (from deepdiff<8.0,>=5.7.0->lightning<2.1,>=2.0->scvi-tools)
#   Downloading ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Collecting starlette (from lightning<2.1,>=2.0->scvi-tools)
#   Downloading starlette-0.22.0-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.3/64.3 kB 10.5 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.4.0 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from starlette->lightning<2.1,>=2.0->scvi-tools) (3.7.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from fsspec<2024.0,>=2022.5.0->lightning<2.1,>=2.0->scvi-tools) (3.8.4)
# Collecting blessed>=1.19.0 (from inquirer<5.0,>=2.10.0->lightning<2.1,>=2.0->scvi-tools)
#   Downloading blessed-1.20.0-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 10.7 MB/s eta 0:00:00
# Collecting python-editor>=1.0.4 (from inquirer<5.0,>=2.10.0->lightning<2.1,>=2.0->scvi-tools)
#   Downloading python_editor-1.0.4-py3-none-any.whl (4.9 kB)
# Collecting readchar>=3.0.6 (from inquirer<5.0,>=2.10.0->lightning<2.1,>=2.0->scvi-tools)
#   Downloading readchar-4.0.5-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from Jinja2<5.0->lightning<2.1,>=2.0->scvi-tools) (2.1.2)
# Collecting pyjwt (from lightning-cloud>=0.5.34->lightning<2.1,>=2.0->scvi-tools)
#   Downloading PyJWT-2.7.0-py3-none-any.whl (22 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=12.0.0->scvi-tools)
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from numba>=0.49->sparse>=0.14.0->scvi-tools) (0.40.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from requests<4.0->lightning<2.1,>=2.0->scvi-tools) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from requests<4.0->lightning<2.1,>=2.0->scvi-tools) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from requests<4.0->lightning<2.1,>=2.0->scvi-tools) (2023.5.7)
# Collecting itsdangerous<3.0.0,>=2.0.1 (from starsessions<2.0,>=1.2.1->lightning<2.1,>=2.0->scvi-tools)
#   Using cached itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Collecting h11>=0.8 (from uvicorn<2.0->lightning<2.1,>=2.0->scvi-tools)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.6 MB/s eta 0:00:00
# Collecting cached_property (from orbax-checkpoint->flax->scvi-tools)
#   Using cached cached_property-1.5.2-py2.py3-none-any.whl (7.6 kB)
# Collecting importlib_resources (from orbax-checkpoint->flax->scvi-tools)
#   Using cached importlib_resources-5.12.0-py3-none-any.whl (36 kB)
# Collecting etils (from orbax-checkpoint->flax->scvi-tools)
#   Downloading etils-1.3.0-py3-none-any.whl (126 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.4/126.4 kB 21.8 MB/s eta 0:00:00
# Requirement already satisfied: nest_asyncio in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from orbax-checkpoint->flax->scvi-tools) (1.5.6)
# Requirement already satisfied: mpmath>=0.19 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from sympy->torch>=1.8.0->scvi-tools) (1.3.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec<2024.0,>=2022.5.0->lightning<2.1,>=2.0->scvi-tools) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec<2024.0,>=2022.5.0->lightning<2.1,>=2.0->scvi-tools) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec<2024.0,>=2022.5.0->lightning<2.1,>=2.0->scvi-tools) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec<2024.0,>=2022.5.0->lightning<2.1,>=2.0->scvi-tools) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec<2024.0,>=2022.5.0->lightning<2.1,>=2.0->scvi-tools) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec<2024.0,>=2022.5.0->lightning<2.1,>=2.0->scvi-tools) (1.3.1)
# Requirement already satisfied: sniffio>=1.1 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette->lightning<2.1,>=2.0->scvi-tools) (1.3.0)
# Requirement already satisfied: exceptiongroup in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette->lightning<2.1,>=2.0->scvi-tools) (1.1.1)
# Requirement already satisfied: wcwidth>=0.1.4 in /home/icb/alessandro.palma/miniconda3/envs/celldreamer/lib/python3.10/site-packages (from blessed>=1.19.0->inquirer<5.0,>=2.10.0->lightning<2.1,>=2.0->scvi-tools) (0.2.6)
# Building wheels for collected packages: docrep, jax, ml-collections
#   Building wheel for docrep (setup.py) ... done
#   Created wheel for docrep: filename=docrep-0.3.2-py3-none-any.whl size=19877 sha256=ba2b541604b17582f537ccf63288e6ff0d688a283afd0ad64c2982e25708150a
#   Stored in directory: /home/icb/alessandro.palma/.cache/pip/wheels/c3/64/48/03c38d8d906159eaa210b3c548fdb590eb3e2a4a5745ae2172
#   Building wheel for jax (pyproject.toml) ... done
#   Created wheel for jax: filename=jax-0.4.12-py3-none-any.whl size=1498447 sha256=27c836896f96e038c9f6f7c825260676779ac6bc5e1442099de181d1e03d88f4
#   Stored in directory: /home/icb/alessandro.palma/.cache/pip/wheels/e8/48/6d/8fc5366c9f000bd18db799e801d5e41c6a7f55d73fd3038b7e
#   Building wheel for ml-collections (setup.py) ... done
#   Created wheel for ml-collections: filename=ml_collections-0.1.1-py3-none-any.whl size=94506 sha256=7b14bf9ac92ab26f07eaa7135276b037dd8b47027c905460c3469170cf80c0c7
#   Stored in directory: /home/icb/alessandro.palma/.cache/pip/wheels/7b/89/c9/a9b87790789e94aadcfc393c283e3ecd5ab916aed0a31be8fe
# Successfully built docrep jax ml-collections
# Installing collected packages: python-editor, pyro-api, msgpack, dm-tree, cached_property, websockets, toolz, tensorstore, readchar, python-multipart, pyjwt, pydantic, ordered-set, opt-einsum, multipledispatch, ml-dtypes, mdurl, itsdangerous, importlib_resources, h11, etils, docrep, contextlib2, blessed, uvicorn, starlette, sparse, ml-collections, markdown-it-py, jaxlib, jax, inquirer, deepdiff, dateutils, croniter, starsessions, rich, orbax-checkpoint, numpyro, fastapi, chex, optax, mudata, lightning-cloud, flax, pyro-ppl, lightning, scvi-tools
# Successfully installed blessed-1.20.0 cached_property-1.5.2 chex-0.1.7 contextlib2-21.6.0 croniter-1.3.15 dateutils-0.6.12 deepdiff-6.3.0 dm-tree-0.1.8 docrep-0.3.2 etils-1.3.0 fastapi-0.88.0 flax-0.6.10 h11-0.14.0 importlib_resources-5.12.0 inquirer-3.1.3 itsdangerous-2.1.2 jax-0.4.12 jaxlib-0.4.12 lightning-2.0.3 lightning-cloud-0.5.36 markdown-it-py-3.0.0 mdurl-0.1.2 ml-collections-0.1.1 ml-dtypes-0.2.0 msgpack-1.0.5 mudata-0.2.3 multipledispatch-0.6.0 numpyro-0.12.1 opt-einsum-3.3.0 optax-0.1.5 orbax-checkpoint-0.2.5 ordered-set-4.1.0 pydantic-1.10.9 pyjwt-2.7.0 pyro-api-0.1.2 pyro-ppl-1.8.5 python-editor-1.0.4 python-multipart-0.0.6 readchar-4.0.5 rich-13.4.2 scvi-tools-1.0.0 sparse-0.14.0 starlette-0.22.0 starsessions-1.3.0 tensorstore-0.1.37 toolz-0.12.0 uvicorn-0.22.0 websockets-11.0.3
# Note: you may need to restart the kernel to use updated packages.
