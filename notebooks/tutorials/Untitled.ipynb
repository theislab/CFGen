# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/nfs/homedirs/pala/celldreamer/checkpoints/try_experiment/generative/try_experiment/version_69/metrics.csv")

# %%
df
# Out:
#       loss/train_loss  epoch   step  loss/valid_loss_step  \
# 0            1.004559    0.0     99                   NaN
# 1            1.004559    0.0    199                   NaN
# 2            1.004559    0.0    299                   NaN
# 3            1.004559    0.0    399                   NaN
# 4            1.004559    0.0    499                   NaN
# ...               ...    ...    ...                   ...
# 2290              NaN    NaN   2241              1.002414
# 2291              NaN    NaN   2242              0.998788
# 2292              NaN    NaN   2243              1.001150
# 2293              NaN   21.0  12561                   NaN
# 2294         0.998544   22.0  12799                   NaN
#
#       loss/valid_loss_epoch
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 2290                    NaN
# 2291                    NaN
# ...

# %%
list(df["loss/train_loss"])
# Out:
# [1.0045592784881592,
#  1.0045592784881592,
#  1.0045592784881592,
#  1.0045592784881592,
#  1.0045592784881592,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  1.0024490356445312,
#  1.0024490356445312,
# ...
